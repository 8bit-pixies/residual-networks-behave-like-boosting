# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
"""Trains a ResNet on the CIFAR10 dataset.

ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf

ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf
"""

import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
from keras.callbacks import Callback

import numpy as np
import pandas as pd
from datetime import datetime
import time
import os
from keras.constraints import Constraint
from keras import initializers, layers
from keras.layers import Lambda

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
depth = n * 6 + 2 # n=3 --> 20, n=5 --> 32, n=7 --> 44, n=9 --> 56

# Model name, depth and version
model_type = 'ResNet%dv%d_noshare' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


class ShrinkageConstraint(Constraint):
    def __init__(self, axis=0):
        self.axis = axis    
    
    def __call__(self, w):
        # apply unitnorm
        #w = w / (K.epsilon() + K.sqrt(K.sum(K.square(w),
        #                                    axis=self.axis,
        #                                    keepdims=True)))
        
        # apply non negative
        w *= K.cast(K.greater_equal(w, 0.), K.floatx())
        # apply max value to be 1
        w *= K.cast(K.less_equal(w, 1.), K.floatx())
        return w


class ShrinkageFactor(layers.Layer):
    """
    This is the sigma object in the algorithm 1 by Beygelzimer (Online Gradient Boosting)
    """
    def __init__(self, step_size, trainable=True, **kwargs):
        self.step_size = step_size
        self.trainable = trainable
        super(ShrinkageFactor, self).__init__(**kwargs)
    
    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.W = self.add_weight(name='highway', 
                                 shape=(1, 1),
                                 initializer=initializers.Zeros(),
                                 constraint=ShrinkageConstraint(),
                                 regularizer=l2(0.01),
                                 trainable=self.trainable)
        self.count = K.variable(0, name="epoch")
        super(ShrinkageFactor, self).build(input_shape)  # Be sure to call this at the end
    
    def call(self, x):
        return (1-self.step_size*self.W)*x
        updates = []
        
        if self.count < 80:
            updates.append((self.count, self.count+1))
            return x
        else:
            updates.append((self.count, self.count+1))
            return (1-self.step_size*self.W)*x
    
    def compute_output_shape(self, input_shape):
        if isinstance(input_shape, list):
            return input_shape[0]
        return input_shape

class TimingCallback(Callback):
    def on_train_begin(self, logs={}):
        self.times = []
    
    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()
    
    def on_epoch_end(self, batch, logs={}):
        # write stuff to disc here...
        self.times.append(time.time() - self.epoch_time_start)

def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 stack=0, 
                 res_block="placeholder"):
    """2D Convolution-Batch Normalization-Activation stack builder
    
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
        
        stack (int): stack number for layer naming purposes
        res_block (string): name of the res_block for naming purposes
    
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4),
                  name=f"resnet_{stack}_{res_block}"
                  )
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization(name=f"bn_{stack}_{res_block}")(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization(f"bn_{stack}_{res_block}")(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_block(x, stack, res_block, num_filters, boost=True):
    strides = 1
    if stack > 0 and res_block == 0:  # first layer but not first stack
        strides = 2  # downsample
    y = resnet_layer(inputs=x,
                     num_filters=num_filters,
                     strides=strides,
                     stack=stack,
                     res_block=f"{res_block}a")
    y = resnet_layer(inputs=y,
                     num_filters=num_filters,
                     activation=None,
                     stack=stack,
                     res_block=f"{res_block}b")
    if stack > 0 and res_block == 0:  # first layer but not first stack
        # linear projection residual shortcut connection to match
        # changed dims
        x = resnet_layer(inputs=x,
                         num_filters=num_filters,
                         kernel_size=1,
                         strides=strides,
                         activation=None,
                         batch_normalization=False,
                         stack=stack,
                         res_block=f"{res_block}c")
    
    if boost:
        step_size = 1.0
        y = ShrinkageFactor(step_size, False, name=f"shrinkage_{stack}_{res_block}")(y)
        # x = Lambda(lambda x: x * step_size, name=f"shrinkage_lambda_{stack}_{res_block}")(x)
    
    x = keras.layers.add([x, y], name=f"add_{stack}_{res_block}")
    x = Activation('relu')(x)
    return x
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 41s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# model = resnet_v1(input_shape=input_shape, depth=depth)
# we shall hardcode the model...with num_res_blocks=3


# model = resnet_v1(input_shape=input_shape, depth=depth)
# we shall hardcode the model...with num_res_blocks=3

num_filters = 16

inputs = Input(shape=input_shape)
x = resnet_layer(inputs=inputs, res_block='preprocessing')

block0_0 = resnet_block(x, 0, 0, num_filters)
block0_1 = resnet_block(block0_0, 0, 1, num_filters)
block0_2 = resnet_block(block0_1, 0, 2, num_filters)

block1_0 = resnet_block(block0_2, 1, 0, num_filters*2)
block1_1 = resnet_block(block1_0, 1, 1, num_filters*2)
block1_2 = resnet_block(block1_1, 1, 2, num_filters*2)

block2_0 = resnet_block(block1_2, 2, 0, num_filters*4)
block2_1 = resnet_block(block2_0, 2, 1, num_filters*4)
block2_2 = resnet_block(block2_1, 2, 2, num_filters*4)

block_output = AveragePooling2D(pool_size=8, name="avg_pool_2_2")(block2_2)
block_output_flatten = Flatten(name="flatten_2_2")(block_output)
#y = Dense(128)(block_output_flatten)

pred_layer_0 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_0')

pred_layer_1 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_1')

pred_layer_2 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_2')
outputs = pred_layer_2(block_output_flatten)


model = Model(inputs=[inputs], outputs=[outputs])
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()

# print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
save_dir = "/content/gdrive/My Drive/colab/weights/"
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

time_cb = TimingCallback()

callbacks = [checkpoint, lr_reducer, lr_scheduler, time_cb]

print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)

# Compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# resnet_0_preprocessing (Conv2D) (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# bn_0_preprocessing (BatchNormal (None, 32, 32, 16)   64          resnet_0_preprocessing[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           bn_0_preprocessing[0][0]
# __________________________________________________________________________________________________
# resnet_0_0a (Conv2D)            (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# bn_0_0a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_0a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           bn_0_0a[0][0]
# __________________________________________________________________________________________________
# resnet_0_0b (Conv2D)            (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# bn_0_0b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_0b[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_0 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_0b[0][0]
# __________________________________________________________________________________________________
# add_0_0 (Add)                   (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  shrinkage_0_0[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_0_0[0][0]
# __________________________________________________________________________________________________
# resnet_0_1a (Conv2D)            (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# bn_0_1a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_1a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           bn_0_1a[0][0]
# __________________________________________________________________________________________________
# resnet_0_1b (Conv2D)            (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# bn_0_1b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_1 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_1b[0][0]
# __________________________________________________________________________________________________
# add_0_1 (Add)                   (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  shrinkage_0_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_0_1[0][0]
# __________________________________________________________________________________________________
# resnet_0_2a (Conv2D)            (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# bn_0_2a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           bn_0_2a[0][0]
# __________________________________________________________________________________________________
# resnet_0_2b (Conv2D)            (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# bn_0_2b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_2 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_2b[0][0]
# __________________________________________________________________________________________________
# add_0_2 (Add)                   (None, 32, 32, 16)   0           activation_5[0][0]
#                                                                  shrinkage_0_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_0_2[0][0]
# __________________________________________________________________________________________________
# resnet_1_0a (Conv2D)            (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# bn_1_0a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_0a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           bn_1_0a[0][0]
# __________________________________________________________________________________________________
# resnet_1_0b (Conv2D)            (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# bn_1_0b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_0b[0][0]
# __________________________________________________________________________________________________
# resnet_1_0c (Conv2D)            (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_0 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_0b[0][0]
# __________________________________________________________________________________________________
# add_1_0 (Add)                   (None, 16, 16, 32)   0           resnet_1_0c[0][0]
#                                                                  shrinkage_1_0[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_1_0[0][0]
# __________________________________________________________________________________________________
# resnet_1_1a (Conv2D)            (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# bn_1_1a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_1a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           bn_1_1a[0][0]
# __________________________________________________________________________________________________
# resnet_1_1b (Conv2D)            (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# bn_1_1b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_1 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_1b[0][0]
# __________________________________________________________________________________________________
# add_1_1 (Add)                   (None, 16, 16, 32)   0           activation_9[0][0]
#                                                                  shrinkage_1_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_1_1[0][0]
# __________________________________________________________________________________________________
# resnet_1_2a (Conv2D)            (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# bn_1_2a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           bn_1_2a[0][0]
# __________________________________________________________________________________________________
# resnet_1_2b (Conv2D)            (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# bn_1_2b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_2 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_2b[0][0]
# __________________________________________________________________________________________________
# add_1_2 (Add)                   (None, 16, 16, 32)   0           activation_11[0][0]
#                                                                  shrinkage_1_2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_1_2[0][0]
# __________________________________________________________________________________________________
# resnet_2_0a (Conv2D)            (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# bn_2_0a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_0a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           bn_2_0a[0][0]
# __________________________________________________________________________________________________
# resnet_2_0b (Conv2D)            (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# bn_2_0b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_0b[0][0]
# __________________________________________________________________________________________________
# resnet_2_0c (Conv2D)            (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_0 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_0b[0][0]
# __________________________________________________________________________________________________
# add_2_0 (Add)                   (None, 8, 8, 64)     0           resnet_2_0c[0][0]
#                                                                  shrinkage_2_0[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_2_0[0][0]
# __________________________________________________________________________________________________
# resnet_2_1a (Conv2D)            (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# bn_2_1a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_1a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           bn_2_1a[0][0]
# __________________________________________________________________________________________________
# resnet_2_1b (Conv2D)            (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# bn_2_1b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_1 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_1b[0][0]
# __________________________________________________________________________________________________
# add_2_1 (Add)                   (None, 8, 8, 64)     0           activation_15[0][0]
#                                                                  shrinkage_2_1[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_2_1[0][0]
# __________________________________________________________________________________________________
# resnet_2_2a (Conv2D)            (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# bn_2_2a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_2a[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           bn_2_2a[0][0]
# __________________________________________________________________________________________________
# resnet_2_2b (Conv2D)            (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# bn_2_2b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_2 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_2b[0][0]
# __________________________________________________________________________________________________
# add_2_2 (Add)                   (None, 8, 8, 64)     0           activation_17[0][0]
#                                                                  shrinkage_2_2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_2_2[0][0]
# __________________________________________________________________________________________________
# avg_pool_2_2 (AveragePooling2D) (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_2_2 (Flatten)           (None, 64)           0           avg_pool_2_2[0][0]
# __________________________________________________________________________________________________
# pred_layer_2 (Dense)            (None, 10)           650         flatten_2_2[0][0]
# ==================================================================================================
# Total params: 274,451
# Trainable params: 273,075
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# Using real-time data augmentation.

# %%
# Fit the model on the batches generated by datagen.flow().
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_test, [y_test]),
                    steps_per_epoch=1600,
                    epochs=epochs, verbose=2, workers=10,
                    callbacks=callbacks)
hist_df = pd.DataFrame(hist.history)
hist_df['times'] = time_cb.times[-hist_df.shape[0]:]
hist_df.to_csv('/content/gdrive/My Drive/colab/weights/training_history_resnetv1_noshare{}.csv'.format(datetime.now().strftime('%Y-%m-%d_%H-%M-%S')), index=True)

# Score trained model.
scores = model.evaluate(x_test, [y_test], verbose=1)
print('Test output:', scores)
# Out:
# Epoch 1/200
# Learning rate:  0.001
#  - 120s - loss: 1.5180 - acc: 0.4937 - val_loss: 1.4964 - val_acc: 0.5172
#
# Epoch 00001: val_acc improved from -inf to 0.51720, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
#  - 113s - loss: 1.1345 - acc: 0.6460 - val_loss: 1.2237 - val_acc: 0.6345
#
# Epoch 00002: val_acc improved from 0.51720 to 0.63450, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
#  - 114s - loss: 0.9812 - acc: 0.7075 - val_loss: 1.1336 - val_acc: 0.6592
#
# Epoch 00003: val_acc improved from 0.63450 to 0.65920, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
#  - 113s - loss: 0.8926 - acc: 0.7420 - val_loss: 1.0386 - val_acc: 0.7084
#
# Epoch 00004: val_acc improved from 0.65920 to 0.70840, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
#  - 116s - loss: 0.8396 - acc: 0.7628 - val_loss: 1.1490 - val_acc: 0.6812
#
# Epoch 00005: val_acc did not improve from 0.70840
# Epoch 6/200
# Learning rate:  0.001
#  - 112s - loss: 0.7952 - acc: 0.7814 - val_loss: 1.0526 - val_acc: 0.7245
#
# Epoch 00006: val_acc improved from 0.70840 to 0.72450, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
#  - 113s - loss: 0.7596 - acc: 0.7951 - val_loss: 1.0537 - val_acc: 0.7063
#
# Epoch 00007: val_acc did not improve from 0.72450
# Epoch 8/200
# Learning rate:  0.001
#  - 111s - loss: 0.7371 - acc: 0.8052 - val_loss: 0.8470 - val_acc: 0.7793
#
# Epoch 00008: val_acc improved from 0.72450 to 0.77930, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.008.h5
# Epoch 9/200
# Learning rate:  0.001
#  - 112s - loss: 0.7144 - acc: 0.8133 - val_loss: 0.8415 - val_acc: 0.7878
#
# Epoch 00009: val_acc improved from 0.77930 to 0.78780, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.009.h5
# Epoch 10/200
# Learning rate:  0.001
#  - 114s - loss: 0.6971 - acc: 0.8205 - val_loss: 0.8255 - val_acc: 0.7824
#
# Epoch 00010: val_acc did not improve from 0.78780
# Epoch 11/200
# Learning rate:  0.001
#  - 111s - loss: 0.6819 - acc: 0.8257 - val_loss: 0.8267 - val_acc: 0.7847
#
# Epoch 00011: val_acc did not improve from 0.78780
# Epoch 12/200
# Learning rate:  0.001
#  - 107s - loss: 0.6716 - acc: 0.8315 - val_loss: 0.8542 - val_acc: 0.7809
#
# Epoch 00012: val_acc did not improve from 0.78780
# Epoch 13/200
# Learning rate:  0.001
#  - 109s - loss: 0.6584 - acc: 0.8364 - val_loss: 1.1411 - val_acc: 0.7242
#
# Epoch 00013: val_acc did not improve from 0.78780
# Epoch 14/200
# Learning rate:  0.001
#  - 109s - loss: 0.6537 - acc: 0.8385 - val_loss: 0.8704 - val_acc: 0.7814
#
# Epoch 00014: val_acc did not improve from 0.78780
# Epoch 15/200
# Learning rate:  0.001
#  - 110s - loss: 0.6385 - acc: 0.8455 - val_loss: 0.8643 - val_acc: 0.7813
#
# Epoch 00015: val_acc did not improve from 0.78780
# Epoch 16/200
# Learning rate:  0.001
#  - 112s - loss: 0.6302 - acc: 0.8480 - val_loss: 0.6812 - val_acc: 0.8338
#
# Epoch 00016: val_acc improved from 0.78780 to 0.83380, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.016.h5
# Epoch 17/200
# Learning rate:  0.001
#  - 115s - loss: 0.6246 - acc: 0.8502 - val_loss: 0.8247 - val_acc: 0.7995
#
# Epoch 00017: val_acc did not improve from 0.83380
# Epoch 18/200
# Learning rate:  0.001
#  - 114s - loss: 0.6156 - acc: 0.8542 - val_loss: 0.8106 - val_acc: 0.7992
#
# Epoch 00018: val_acc did not improve from 0.83380
# Epoch 19/200
# Learning rate:  0.001
#  - 113s - loss: 0.6077 - acc: 0.8561 - val_loss: 0.6807 - val_acc: 0.8368
#
# Epoch 00019: val_acc improved from 0.83380 to 0.83680, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.019.h5
# Epoch 20/200
# Learning rate:  0.001
#  - 113s - loss: 0.6038 - acc: 0.8585 - val_loss: 0.8574 - val_acc: 0.7892
#
# Epoch 00020: val_acc did not improve from 0.83680
# Epoch 21/200
# Learning rate:  0.001
#  - 107s - loss: 0.6007 - acc: 0.8603 - val_loss: 0.8913 - val_acc: 0.7839
#
# Epoch 00021: val_acc did not improve from 0.83680
# Epoch 22/200
# Learning rate:  0.001
#  - 108s - loss: 0.5967 - acc: 0.8623 - val_loss: 0.8552 - val_acc: 0.7880
#
# Epoch 00022: val_acc did not improve from 0.83680
# Epoch 23/200
# Learning rate:  0.001
#  - 108s - loss: 0.5934 - acc: 0.8629 - val_loss: 0.7867 - val_acc: 0.8136
#
# Epoch 00023: val_acc did not improve from 0.83680
# Epoch 24/200
# Learning rate:  0.001
#  - 109s - loss: 0.5860 - acc: 0.8648 - val_loss: 0.8649 - val_acc: 0.7937
#
# Epoch 00024: val_acc did not improve from 0.83680
# Epoch 25/200
# Learning rate:  0.001
#  - 110s - loss: 0.5831 - acc: 0.8671 - val_loss: 0.7987 - val_acc: 0.8056
#
# Epoch 00025: val_acc did not improve from 0.83680
# Epoch 26/200
# Learning rate:  0.001
#  - 111s - loss: 0.5767 - acc: 0.8696 - val_loss: 0.7092 - val_acc: 0.8310
#
# Epoch 00026: val_acc did not improve from 0.83680
# Epoch 27/200
# Learning rate:  0.001
#  - 114s - loss: 0.5794 - acc: 0.8671 - val_loss: 0.8724 - val_acc: 0.7878
#
# Epoch 00027: val_acc did not improve from 0.83680
# Epoch 28/200
# Learning rate:  0.001
#  - 112s - loss: 0.5717 - acc: 0.8732 - val_loss: 0.7645 - val_acc: 0.8242
#
# Epoch 00028: val_acc did not improve from 0.83680
# Epoch 29/200
# Learning rate:  0.001
#  - 114s - loss: 0.5711 - acc: 0.8707 - val_loss: 0.7593 - val_acc: 0.8193
#
# Epoch 00029: val_acc did not improve from 0.83680
# Epoch 30/200
# Learning rate:  0.001
#  - 113s - loss: 0.5653 - acc: 0.8735 - val_loss: 0.7867 - val_acc: 0.8149
#
# Epoch 00030: val_acc did not improve from 0.83680
# Epoch 31/200
# Learning rate:  0.001
#  - 113s - loss: 0.5610 - acc: 0.8767 - val_loss: 0.6545 - val_acc: 0.8441
#
# Epoch 00031: val_acc improved from 0.83680 to 0.84410, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.031.h5
# Epoch 32/200
# Learning rate:  0.001
#  - 113s - loss: 0.5635 - acc: 0.8755 - val_loss: 0.6866 - val_acc: 0.8338
#
# Epoch 00032: val_acc did not improve from 0.84410
# Epoch 33/200
# Learning rate:  0.001
#  - 113s - loss: 0.5484 - acc: 0.8802 - val_loss: 0.6706 - val_acc: 0.8457
#
# Epoch 00033: val_acc improved from 0.84410 to 0.84570, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.033.h5
# Epoch 34/200
# Learning rate:  0.001
#  - 113s - loss: 0.5519 - acc: 0.8797 - val_loss: 0.7456 - val_acc: 0.8266
#
# Epoch 00034: val_acc did not improve from 0.84570
# Epoch 35/200
# Learning rate:  0.001
#  - 112s - loss: 0.5499 - acc: 0.8824 - val_loss: 0.9910 - val_acc: 0.7617
#
# Epoch 00035: val_acc did not improve from 0.84570
# Epoch 36/200
# Learning rate:  0.001
#  - 113s - loss: 0.5473 - acc: 0.8822 - val_loss: 0.7364 - val_acc: 0.8248
#
# Epoch 00036: val_acc did not improve from 0.84570
# Epoch 37/200
# Learning rate:  0.001
#  - 112s - loss: 0.5484 - acc: 0.8816 - val_loss: 0.6436 - val_acc: 0.8596
#
# Epoch 00037: val_acc improved from 0.84570 to 0.85960, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.037.h5
# Epoch 38/200
# Learning rate:  0.001
#  - 113s - loss: 0.5406 - acc: 0.8842 - val_loss: 0.7516 - val_acc: 0.8265
#
# Epoch 00038: val_acc did not improve from 0.85960
# Epoch 39/200
# Learning rate:  0.001
#  - 113s - loss: 0.5424 - acc: 0.8848 - val_loss: 0.6943 - val_acc: 0.8396
#
# Epoch 00039: val_acc did not improve from 0.85960
# Epoch 40/200
# Learning rate:  0.001
#  - 112s - loss: 0.5398 - acc: 0.8860 - val_loss: 0.7250 - val_acc: 0.8253
#
# Epoch 00040: val_acc did not improve from 0.85960
# Epoch 41/200
# Learning rate:  0.001
#  - 113s - loss: 0.5413 - acc: 0.8835 - val_loss: 0.8088 - val_acc: 0.8110
#
# Epoch 00041: val_acc did not improve from 0.85960
# Epoch 42/200
# Learning rate:  0.001
#  - 114s - loss: 0.5362 - acc: 0.8854 - val_loss: 0.8020 - val_acc: 0.8161
#
# Epoch 00042: val_acc did not improve from 0.85960
# Epoch 43/200
# Learning rate:  0.001
#  - 114s - loss: 0.5332 - acc: 0.8873 - val_loss: 0.6897 - val_acc: 0.8419
#
# Epoch 00043: val_acc did not improve from 0.85960
# Epoch 44/200
# Learning rate:  0.001
#  - 114s - loss: 0.5312 - acc: 0.8878 - val_loss: 0.6529 - val_acc: 0.8582
#
# Epoch 00044: val_acc did not improve from 0.85960
# Epoch 45/200
# Learning rate:  0.001
#  - 113s - loss: 0.5301 - acc: 0.8880 - val_loss: 0.7226 - val_acc: 0.8316
#
# Epoch 00045: val_acc did not improve from 0.85960
# Epoch 46/200
# Learning rate:  0.001
#  - 114s - loss: 0.5300 - acc: 0.8874 - val_loss: 0.7990 - val_acc: 0.8172
#
# Epoch 00046: val_acc did not improve from 0.85960
# Epoch 47/200
# Learning rate:  0.001
#  - 113s - loss: 0.5196 - acc: 0.8924 - val_loss: 0.6456 - val_acc: 0.8587
#
# Epoch 00047: val_acc did not improve from 0.85960
# Epoch 48/200
# Learning rate:  0.001
#  - 112s - loss: 0.5255 - acc: 0.8896 - val_loss: 0.6687 - val_acc: 0.8516
#
# Epoch 00048: val_acc did not improve from 0.85960
# Epoch 49/200
# Learning rate:  0.001
#  - 113s - loss: 0.5206 - acc: 0.8930 - val_loss: 0.6561 - val_acc: 0.8534
#
# Epoch 00049: val_acc did not improve from 0.85960
# Epoch 50/200
# Learning rate:  0.001
#  - 113s - loss: 0.5227 - acc: 0.8911 - val_loss: 0.6941 - val_acc: 0.8412
#
# Epoch 00050: val_acc did not improve from 0.85960
# Epoch 51/200
# Learning rate:  0.001
#  - 112s - loss: 0.5211 - acc: 0.8921 - val_loss: 0.6509 - val_acc: 0.8570
#
# Epoch 00051: val_acc did not improve from 0.85960
# Epoch 52/200
# Learning rate:  0.001
#  - 113s - loss: 0.5253 - acc: 0.8906 - val_loss: 0.6727 - val_acc: 0.8456
#
# Epoch 00052: val_acc did not improve from 0.85960
# Epoch 53/200
# Learning rate:  0.001
#  - 113s - loss: 0.5123 - acc: 0.8922 - val_loss: 0.7216 - val_acc: 0.8298
#
# Epoch 00053: val_acc did not improve from 0.85960
# Epoch 54/200
# Learning rate:  0.001
#  - 113s - loss: 0.5174 - acc: 0.8928 - val_loss: 0.8419 - val_acc: 0.8071
#
# Epoch 00054: val_acc did not improve from 0.85960
# Epoch 55/200
# Learning rate:  0.001
#  - 113s - loss: 0.5200 - acc: 0.8922 - val_loss: 0.7015 - val_acc: 0.8480
#
# Epoch 00055: val_acc did not improve from 0.85960
# Epoch 56/200
# Learning rate:  0.001
#  - 113s - loss: 0.5175 - acc: 0.8926 - val_loss: 0.7921 - val_acc: 0.8223
#
# Epoch 00056: val_acc did not improve from 0.85960
# Epoch 57/200
# Learning rate:  0.001
#  - 114s - loss: 0.5148 - acc: 0.8934 - val_loss: 0.6576 - val_acc: 0.8524
#
# Epoch 00057: val_acc did not improve from 0.85960
# Epoch 58/200
# Learning rate:  0.001
#  - 114s - loss: 0.5123 - acc: 0.8951 - val_loss: 0.6558 - val_acc: 0.8491
#
# Epoch 00058: val_acc did not improve from 0.85960
# Epoch 59/200
# Learning rate:  0.001
#  - 115s - loss: 0.5129 - acc: 0.8948 - val_loss: 0.5971 - val_acc: 0.8745
#
# Epoch 00059: val_acc improved from 0.85960 to 0.87450, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.059.h5
# Epoch 60/200
# Learning rate:  0.001
#  - 114s - loss: 0.5090 - acc: 0.8958 - val_loss: 0.6951 - val_acc: 0.8426
#
# Epoch 00060: val_acc did not improve from 0.87450
# Epoch 61/200
# Learning rate:  0.001
#  - 114s - loss: 0.5092 - acc: 0.8949 - val_loss: 0.7359 - val_acc: 0.8315
#
# Epoch 00061: val_acc did not improve from 0.87450
# Epoch 62/200
# Learning rate:  0.001
#  - 114s - loss: 0.5102 - acc: 0.8944 - val_loss: 0.6361 - val_acc: 0.8633
#
# Epoch 00062: val_acc did not improve from 0.87450
# Epoch 63/200
# Learning rate:  0.001
#  - 114s - loss: 0.5035 - acc: 0.8980 - val_loss: 0.6716 - val_acc: 0.8497
#
# Epoch 00063: val_acc did not improve from 0.87450
# Epoch 64/200
# Learning rate:  0.001
#  - 114s - loss: 0.5092 - acc: 0.8947 - val_loss: 0.6445 - val_acc: 0.8578
#
# Epoch 00064: val_acc did not improve from 0.87450
# Epoch 65/200
# Learning rate:  0.001
#  - 113s - loss: 0.5024 - acc: 0.8979 - val_loss: 0.6860 - val_acc: 0.8472
#
# Epoch 00065: val_acc did not improve from 0.87450
# Epoch 66/200
# Learning rate:  0.001
#  - 113s - loss: 0.5008 - acc: 0.8984 - val_loss: 0.6215 - val_acc: 0.8680
#
# Epoch 00066: val_acc did not improve from 0.87450
# Epoch 67/200
# Learning rate:  0.001
#  - 114s - loss: 0.5033 - acc: 0.8957 - val_loss: 0.6765 - val_acc: 0.8551
#
# Epoch 00067: val_acc did not improve from 0.87450
# Epoch 68/200
# Learning rate:  0.001
#  - 114s - loss: 0.5003 - acc: 0.8984 - val_loss: 0.7597 - val_acc: 0.8311
#
# Epoch 00068: val_acc did not improve from 0.87450
# Epoch 69/200
# Learning rate:  0.001
#  - 114s - loss: 0.4989 - acc: 0.8996 - val_loss: 0.6412 - val_acc: 0.8624
#
# Epoch 00069: val_acc did not improve from 0.87450
# Epoch 70/200
# Learning rate:  0.001
#  - 112s - loss: 0.4951 - acc: 0.8997 - val_loss: 0.5942 - val_acc: 0.8689
#
# Epoch 00070: val_acc did not improve from 0.87450
# Epoch 71/200
# Learning rate:  0.001
#  - 107s - loss: 0.4933 - acc: 0.9007 - val_loss: 0.6864 - val_acc: 0.8452
#
# Epoch 00071: val_acc did not improve from 0.87450
# Epoch 72/200
# Learning rate:  0.001
#  - 106s - loss: 0.4996 - acc: 0.8983 - val_loss: 0.6152 - val_acc: 0.8671
#
# Epoch 00072: val_acc did not improve from 0.87450
# Epoch 73/200
# Learning rate:  0.001
#  - 108s - loss: 0.4925 - acc: 0.9011 - val_loss: 0.6447 - val_acc: 0.8584
#
# Epoch 00073: val_acc did not improve from 0.87450
# Epoch 74/200
# Learning rate:  0.001
#  - 106s - loss: 0.5009 - acc: 0.8998 - val_loss: 0.6066 - val_acc: 0.8680
#
# Epoch 00074: val_acc did not improve from 0.87450
# Epoch 75/200
# Learning rate:  0.001
#  - 104s - loss: 0.4959 - acc: 0.8997 - val_loss: 0.6392 - val_acc: 0.8600
#
# Epoch 00075: val_acc did not improve from 0.87450
# Epoch 76/200
# Learning rate:  0.001
#  - 106s - loss: 0.4942 - acc: 0.9013 - val_loss: 0.7481 - val_acc: 0.8309
#
# Epoch 00076: val_acc did not improve from 0.87450
# Epoch 77/200
# Learning rate:  0.001
#  - 107s - loss: 0.4967 - acc: 0.9015 - val_loss: 0.7631 - val_acc: 0.8325
#
# Epoch 00077: val_acc did not improve from 0.87450
# Epoch 78/200
# Learning rate:  0.001
#  - 106s - loss: 0.4916 - acc: 0.9033 - val_loss: 0.6660 - val_acc: 0.8502
#
# Epoch 00078: val_acc did not improve from 0.87450
# Epoch 79/200
# Learning rate:  0.001
#  - 105s - loss: 0.4919 - acc: 0.9029 - val_loss: 0.6206 - val_acc: 0.8632
#
# Epoch 00079: val_acc did not improve from 0.87450
# Epoch 80/200
# Learning rate:  0.001
#  - 106s - loss: 0.4922 - acc: 0.9004 - val_loss: 0.6737 - val_acc: 0.8495
#
# Epoch 00080: val_acc did not improve from 0.87450
# Epoch 81/200
# Learning rate:  0.001
#  - 112s - loss: 0.4915 - acc: 0.9027 - val_loss: 0.7011 - val_acc: 0.8439
#
# Epoch 00081: val_acc did not improve from 0.87450
# Epoch 82/200
# Learning rate:  0.0001
#  - 105s - loss: 0.4054 - acc: 0.9317 - val_loss: 0.5039 - val_acc: 0.8997
#
# Epoch 00082: val_acc improved from 0.87450 to 0.89970, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
#  - 104s - loss: 0.3741 - acc: 0.9415 - val_loss: 0.4869 - val_acc: 0.9038
#
# Epoch 00083: val_acc improved from 0.89970 to 0.90380, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
#  - 109s - loss: 0.3555 - acc: 0.9463 - val_loss: 0.4840 - val_acc: 0.9041
#
# Epoch 00084: val_acc improved from 0.90380 to 0.90410, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
#  - 107s - loss: 0.3434 - acc: 0.9490 - val_loss: 0.4739 - val_acc: 0.9089
#
# Epoch 00085: val_acc improved from 0.90410 to 0.90890, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
#  - 104s - loss: 0.3376 - acc: 0.9499 - val_loss: 0.4721 - val_acc: 0.9079
#
# Epoch 00086: val_acc did not improve from 0.90890
# Epoch 87/200
# Learning rate:  0.0001
#  - 109s - loss: 0.3277 - acc: 0.9509 - val_loss: 0.4677 - val_acc: 0.9079
#
# Epoch 00087: val_acc did not improve from 0.90890
# Epoch 88/200
# Learning rate:  0.0001
#  - 105s - loss: 0.3187 - acc: 0.9541 - val_loss: 0.4617 - val_acc: 0.9125
#
# Epoch 00088: val_acc improved from 0.90890 to 0.91250, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.088.h5
# Epoch 89/200
# Learning rate:  0.0001
#  - 104s - loss: 0.3107 - acc: 0.9551 - val_loss: 0.4646 - val_acc: 0.9092
#
# Epoch 00089: val_acc did not improve from 0.91250
# Epoch 90/200
# Learning rate:  0.0001
#  - 104s - loss: 0.3046 - acc: 0.9564 - val_loss: 0.4638 - val_acc: 0.9104
#
# Epoch 00090: val_acc did not improve from 0.91250
# Epoch 91/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2978 - acc: 0.9573 - val_loss: 0.4561 - val_acc: 0.9122
#
# Epoch 00091: val_acc did not improve from 0.91250
# Epoch 92/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2933 - acc: 0.9576 - val_loss: 0.4483 - val_acc: 0.9148
#
# Epoch 00092: val_acc improved from 0.91250 to 0.91480, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.092.h5
# Epoch 93/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2888 - acc: 0.9581 - val_loss: 0.4645 - val_acc: 0.9120
#
# Epoch 00093: val_acc did not improve from 0.91480
# Epoch 94/200
# Learning rate:  0.0001
#  - 107s - loss: 0.2836 - acc: 0.9596 - val_loss: 0.4656 - val_acc: 0.9089
#
# Epoch 00094: val_acc did not improve from 0.91480
# Epoch 95/200
# Learning rate:  0.0001
#  - 107s - loss: 0.2765 - acc: 0.9610 - val_loss: 0.4485 - val_acc: 0.9126
#
# Epoch 00095: val_acc did not improve from 0.91480
# Epoch 96/200
# Learning rate:  0.0001
#  - 103s - loss: 0.2728 - acc: 0.9616 - val_loss: 0.4589 - val_acc: 0.9107
#
# Epoch 00096: val_acc did not improve from 0.91480
# Epoch 97/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2691 - acc: 0.9632 - val_loss: 0.4569 - val_acc: 0.9113
#
# Epoch 00097: val_acc did not improve from 0.91480
# Epoch 98/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2613 - acc: 0.9647 - val_loss: 0.4406 - val_acc: 0.9149
#
# Epoch 00098: val_acc improved from 0.91480 to 0.91490, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.098.h5
# Epoch 99/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2625 - acc: 0.9641 - val_loss: 0.4597 - val_acc: 0.9081
#
# Epoch 00099: val_acc did not improve from 0.91490
# Epoch 100/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2557 - acc: 0.9651 - val_loss: 0.4443 - val_acc: 0.9127
#
# Epoch 00100: val_acc did not improve from 0.91490
# Epoch 101/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2558 - acc: 0.9646 - val_loss: 0.4438 - val_acc: 0.9128
#
# Epoch 00101: val_acc did not improve from 0.91490
# Epoch 102/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2496 - acc: 0.9664 - val_loss: 0.4418 - val_acc: 0.9129
#
# Epoch 00102: val_acc did not improve from 0.91490
# Epoch 103/200
# Learning rate:  0.0001
#  - 106s - loss: 0.2471 - acc: 0.9667 - val_loss: 0.4549 - val_acc: 0.9104
#
# Epoch 00103: val_acc did not improve from 0.91490
# Epoch 104/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2442 - acc: 0.9668 - val_loss: 0.4508 - val_acc: 0.9123
#
# Epoch 00104: val_acc did not improve from 0.91490
# Epoch 105/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2404 - acc: 0.9682 - val_loss: 0.4423 - val_acc: 0.9133
#
# Epoch 00105: val_acc did not improve from 0.91490
# Epoch 106/200
# Learning rate:  0.0001
#  - 106s - loss: 0.2381 - acc: 0.9673 - val_loss: 0.4449 - val_acc: 0.9134
#
# Epoch 00106: val_acc did not improve from 0.91490
# Epoch 107/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2354 - acc: 0.9690 - val_loss: 0.4444 - val_acc: 0.9129
#
# Epoch 00107: val_acc did not improve from 0.91490
# Epoch 108/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2333 - acc: 0.9686 - val_loss: 0.4586 - val_acc: 0.9084
#
# Epoch 00108: val_acc did not improve from 0.91490
# Epoch 109/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2274 - acc: 0.9707 - val_loss: 0.4589 - val_acc: 0.9102
#
# Epoch 00109: val_acc did not improve from 0.91490
# Epoch 110/200
# Learning rate:  0.0001
#  - 107s - loss: 0.2294 - acc: 0.9684 - val_loss: 0.4539 - val_acc: 0.9108
#
# Epoch 00110: val_acc did not improve from 0.91490
# Epoch 111/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2251 - acc: 0.9701 - val_loss: 0.4422 - val_acc: 0.9117
#
# Epoch 00111: val_acc did not improve from 0.91490
# Epoch 112/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2205 - acc: 0.9719 - val_loss: 0.4518 - val_acc: 0.9107
#
# Epoch 00112: val_acc did not improve from 0.91490
# Epoch 113/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2203 - acc: 0.9712 - val_loss: 0.4501 - val_acc: 0.9120
#
# Epoch 00113: val_acc did not improve from 0.91490
# Epoch 114/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2177 - acc: 0.9712 - val_loss: 0.4459 - val_acc: 0.9142
#
# Epoch 00114: val_acc did not improve from 0.91490
# Epoch 115/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2142 - acc: 0.9716 - val_loss: 0.4487 - val_acc: 0.9123
#
# Epoch 00115: val_acc did not improve from 0.91490
# Epoch 116/200
# Learning rate:  0.0001
#  - 103s - loss: 0.2117 - acc: 0.9726 - val_loss: 0.4525 - val_acc: 0.9106
#
# Epoch 00116: val_acc did not improve from 0.91490
# Epoch 117/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2097 - acc: 0.9723 - val_loss: 0.4456 - val_acc: 0.9128
#
# Epoch 00117: val_acc did not improve from 0.91490
# Epoch 118/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2077 - acc: 0.9732 - val_loss: 0.4631 - val_acc: 0.9092
#
# Epoch 00118: val_acc did not improve from 0.91490
# Epoch 119/200
# Learning rate:  0.0001
#  - 105s - loss: 0.2076 - acc: 0.9730 - val_loss: 0.4586 - val_acc: 0.9092
#
# Epoch 00119: val_acc did not improve from 0.91490
# Epoch 120/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2024 - acc: 0.9746 - val_loss: 0.4747 - val_acc: 0.9046
#
# Epoch 00120: val_acc did not improve from 0.91490
# Epoch 121/200
# Learning rate:  0.0001
#  - 104s - loss: 0.2016 - acc: 0.9750 - val_loss: 0.4535 - val_acc: 0.9117
#
# Epoch 00121: val_acc did not improve from 0.91490
# Epoch 122/200
# Learning rate:  1e-05
#  - 103s - loss: 0.1940 - acc: 0.9780 - val_loss: 0.4426 - val_acc: 0.9130
#
# Epoch 00122: val_acc did not improve from 0.91490
# Epoch 123/200
# Learning rate:  1e-05
#  - 104s - loss: 0.1907 - acc: 0.9788 - val_loss: 0.4392 - val_acc: 0.9137
#
# Epoch 00123: val_acc did not improve from 0.91490
# Epoch 124/200
# Learning rate:  1e-05
#  - 104s - loss: 0.1891 - acc: 0.9787 - val_loss: 0.4370 - val_acc: 0.9150
#
# Epoch 00124: val_acc improved from 0.91490 to 0.91500, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.124.h5
# Epoch 125/200
# Learning rate:  1e-05
#  - 102s - loss: 0.1873 - acc: 0.9794 - val_loss: 0.4380 - val_acc: 0.9150
#
# Epoch 00125: val_acc did not improve from 0.91500
# Epoch 126/200
# Learning rate:  1e-05
#  - 103s - loss: 0.1875 - acc: 0.9796 - val_loss: 0.4370 - val_acc: 0.9159
#
# Epoch 00126: val_acc improved from 0.91500 to 0.91590, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.126.h5
# Epoch 127/200
# Learning rate:  1e-05
#  - 104s - loss: 0.1848 - acc: 0.9803 - val_loss: 0.4386 - val_acc: 0.9155
#
# Epoch 00127: val_acc did not improve from 0.91590
# Epoch 128/200
# Learning rate:  1e-05
#  - 103s - loss: 0.1840 - acc: 0.9804 - val_loss: 0.4359 - val_acc: 0.9158
#
# Epoch 00128: val_acc did not improve from 0.91590
# Epoch 129/200
# Learning rate:  1e-05
#  - 103s - loss: 0.1857 - acc: 0.9800 - val_loss: 0.4366 - val_acc: 0.9162
#
# Epoch 00129: val_acc improved from 0.91590 to 0.91620, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.129.h5
# Epoch 130/200
# Learning rate:  1e-05
#  - 110s - loss: 0.1811 - acc: 0.9817 - val_loss: 0.4373 - val_acc: 0.9156
#
# Epoch 00130: val_acc did not improve from 0.91620
# Epoch 131/200
# Learning rate:  1e-05
#  - 107s - loss: 0.1807 - acc: 0.9821 - val_loss: 0.4372 - val_acc: 0.9149
#
# Epoch 00131: val_acc did not improve from 0.91620
# Epoch 132/200
# Learning rate:  1e-05
#  - 106s - loss: 0.1812 - acc: 0.9818 - val_loss: 0.4360 - val_acc: 0.9179
#
# Epoch 00132: val_acc improved from 0.91620 to 0.91790, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.132.h5
# Epoch 133/200
# Learning rate:  1e-05
#  - 105s - loss: 0.1834 - acc: 0.9805 - val_loss: 0.4368 - val_acc: 0.9168
#
# Epoch 00133: val_acc did not improve from 0.91790
# Epoch 134/200
# Learning rate:  1e-05
#  - 104s - loss: 0.1795 - acc: 0.9815 - val_loss: 0.4385 - val_acc: 0.9166
#
# Epoch 00134: val_acc did not improve from 0.91790
# Epoch 135/200
# Learning rate:  1e-05
#  - 104s - loss: 0.1824 - acc: 0.9807 - val_loss: 0.4399 - val_acc: 0.9165
#
# Epoch 00135: val_acc did not improve from 0.91790
# Epoch 136/200
# Learning rate:  1e-05
#  - 105s - loss: 0.1831 - acc: 0.9802 - val_loss: 0.4369 - val_acc: 0.9175
#
# Epoch 00136: val_acc did not improve from 0.91790
# Epoch 137/200
# Learning rate:  1e-05
#  - 106s - loss: 0.1814 - acc: 0.9806 - val_loss: 0.4355 - val_acc: 0.9171
#
# Epoch 00137: val_acc did not improve from 0.91790
# Epoch 138/200
# Learning rate:  1e-05
#  - 106s - loss: 0.1795 - acc: 0.9816 - val_loss: 0.4356 - val_acc: 0.9160
#
# Epoch 00138: val_acc did not improve from 0.91790
# Epoch 139/200
# Learning rate:  1e-05
#  - 107s - loss: 0.1779 - acc: 0.9826 - val_loss: 0.4373 - val_acc: 0.9165
#
# Epoch 00139: val_acc did not improve from 0.91790
# Epoch 140/200
# Learning rate:  1e-05
#  - 107s - loss: 0.1783 - acc: 0.9821 - val_loss: 0.4384 - val_acc: 0.9163
#
# Epoch 00140: val_acc did not improve from 0.91790
# Epoch 141/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1779 - acc: 0.9824 - val_loss: 0.4392 - val_acc: 0.9167
#
# Epoch 00141: val_acc did not improve from 0.91790
# Epoch 142/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1768 - acc: 0.9827 - val_loss: 0.4374 - val_acc: 0.9169
#
# Epoch 00142: val_acc did not improve from 0.91790
# Epoch 143/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1771 - acc: 0.9827 - val_loss: 0.4405 - val_acc: 0.9161
#
# Epoch 00143: val_acc did not improve from 0.91790
# Epoch 144/200
# Learning rate:  1e-05
#  - 109s - loss: 0.1763 - acc: 0.9828 - val_loss: 0.4350 - val_acc: 0.9172
#
# Epoch 00144: val_acc did not improve from 0.91790
# Epoch 145/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1774 - acc: 0.9821 - val_loss: 0.4369 - val_acc: 0.9181
#
# Epoch 00145: val_acc improved from 0.91790 to 0.91810, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.145.h5
# Epoch 146/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1744 - acc: 0.9836 - val_loss: 0.4402 - val_acc: 0.9162
#
# Epoch 00146: val_acc did not improve from 0.91810
# Epoch 147/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1758 - acc: 0.9825 - val_loss: 0.4352 - val_acc: 0.9180
#
# Epoch 00147: val_acc did not improve from 0.91810
# Epoch 148/200
# Learning rate:  1e-05
#  - 110s - loss: 0.1752 - acc: 0.9827 - val_loss: 0.4373 - val_acc: 0.9187
#
# Epoch 00148: val_acc improved from 0.91810 to 0.91870, saving model to /content/gdrive/My Drive/colab/weights/cifar10_ResNet20v1_noshare_model.148.h5
# Epoch 149/200
# Learning rate:  1e-05
#  - 109s - loss: 0.1739 - acc: 0.9829 - val_loss: 0.4397 - val_acc: 0.9180
#
# Epoch 00149: val_acc did not improve from 0.91870
# Epoch 150/200
# Learning rate:  1e-05
#  - 108s - loss: 0.1746 - acc: 0.9831 - val_loss: 0.4418 - val_acc: 0.9164
#
# Epoch 00150: val_acc did not improve from 0.91870
# Epoch 151/200
# Learning rate:  1e-05
#  - 112s - loss: 0.1747 - acc: 0.9822 - val_loss: 0.4423 - val_acc: 0.9176
#
# Epoch 00151: val_acc did not improve from 0.91870
# Epoch 152/200
# Learning rate:  1e-05
#  - 114s - loss: 0.1723 - acc: 0.9833 - val_loss: 0.4375 - val_acc: 0.9170
#
# Epoch 00152: val_acc did not improve from 0.91870
# Epoch 153/200
# Learning rate:  1e-05
#  - 115s - loss: 0.1749 - acc: 0.9826 - val_loss: 0.4389 - val_acc: 0.9180
#
# Epoch 00153: val_acc did not improve from 0.91870
# Epoch 154/200
# Learning rate:  1e-05
#  - 115s - loss: 0.1737 - acc: 0.9827 - val_loss: 0.4403 - val_acc: 0.9178
#
# Epoch 00154: val_acc did not improve from 0.91870
# Epoch 155/200
# Learning rate:  1e-05
#  - 115s - loss: 0.1699 - acc: 0.9845 - val_loss: 0.4419 - val_acc: 0.9175
#
# Epoch 00155: val_acc did not improve from 0.91870
# Epoch 156/200
# Learning rate:  1e-05
#  - 116s - loss: 0.1737 - acc: 0.9822 - val_loss: 0.4382 - val_acc: 0.9179
#
# Epoch 00156: val_acc did not improve from 0.91870
# Epoch 157/200
# Learning rate:  1e-05
#  - 116s - loss: 0.1706 - acc: 0.9838 - val_loss: 0.4419 - val_acc: 0.9171
#
# Epoch 00157: val_acc did not improve from 0.91870
# Epoch 158/200
# Learning rate:  1e-05
#  - 116s - loss: 0.1707 - acc: 0.9840 - val_loss: 0.4378 - val_acc: 0.9178
#
# Epoch 00158: val_acc did not improve from 0.91870
# Epoch 159/200
# Learning rate:  1e-05
#  - 116s - loss: 0.1691 - acc: 0.9843 - val_loss: 0.4433 - val_acc: 0.9176
#
# Epoch 00159: val_acc did not improve from 0.91870
# Epoch 160/200
# Learning rate:  1e-05
#  - 116s - loss: 0.1710 - acc: 0.9836 - val_loss: 0.4399 - val_acc: 0.9177
#
# Epoch 00160: val_acc did not improve from 0.91870
# Epoch 161/200
# Learning rate:  1e-05
#  - 117s - loss: 0.1687 - acc: 0.9841 - val_loss: 0.4433 - val_acc: 0.9168
#
# Epoch 00161: val_acc did not improve from 0.91870
# Epoch 162/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1690 - acc: 0.9846 - val_loss: 0.4420 - val_acc: 0.9172
#
# Epoch 00162: val_acc did not improve from 0.91870
# Epoch 163/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1680 - acc: 0.9841 - val_loss: 0.4423 - val_acc: 0.9169
#
# Epoch 00163: val_acc did not improve from 0.91870
# Epoch 164/200
# Learning rate:  1e-06
#  - 117s - loss: 0.1705 - acc: 0.9833 - val_loss: 0.4412 - val_acc: 0.9164
#
# Epoch 00164: val_acc did not improve from 0.91870
# Epoch 165/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1699 - acc: 0.9840 - val_loss: 0.4402 - val_acc: 0.9174
#
# Epoch 00165: val_acc did not improve from 0.91870
# Epoch 166/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1686 - acc: 0.9841 - val_loss: 0.4436 - val_acc: 0.9172
#
# Epoch 00166: val_acc did not improve from 0.91870
# Epoch 167/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1704 - acc: 0.9830 - val_loss: 0.4421 - val_acc: 0.9179
#
# Epoch 00167: val_acc did not improve from 0.91870
# Epoch 168/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1687 - acc: 0.9847 - val_loss: 0.4424 - val_acc: 0.9176
#
# Epoch 00168: val_acc did not improve from 0.91870
# Epoch 169/200
# Learning rate:  1e-06
#  - 116s - loss: 0.1707 - acc: 0.9842 - val_loss: 0.4412 - val_acc: 0.9179
#
# Epoch 00169: val_acc did not improve from 0.91870
# Epoch 170/200
# Learning rate:  1e-06
#  - 113s - loss: 0.1697 - acc: 0.9844 - val_loss: 0.4420 - val_acc: 0.9176
#
# Epoch 00170: val_acc did not improve from 0.91870
# Epoch 171/200
# Learning rate:  1e-06
#  - 113s - loss: 0.1672 - acc: 0.9849 - val_loss: 0.4419 - val_acc: 0.9178
#
# Epoch 00171: val_acc did not improve from 0.91870
# Epoch 172/200
# Learning rate:  1e-06
#  - 111s - loss: 0.1695 - acc: 0.9837 - val_loss: 0.4399 - val_acc: 0.9175
#
# Epoch 00172: val_acc did not improve from 0.91870
# Epoch 173/200
# Learning rate:  1e-06
#  - 111s - loss: 0.1703 - acc: 0.9833 - val_loss: 0.4409 - val_acc: 0.9173
#
# Epoch 00173: val_acc did not improve from 0.91870
# Epoch 174/200
# Learning rate:  1e-06
#  - 110s - loss: 0.1691 - acc: 0.9839 - val_loss: 0.4399 - val_acc: 0.9174
#
# Epoch 00174: val_acc did not improve from 0.91870
# Epoch 175/200
# Learning rate:  1e-06
#  - 111s - loss: 0.1695 - acc: 0.9836 - val_loss: 0.4402 - val_acc: 0.9182
#
# Epoch 00175: val_acc did not improve from 0.91870
# Epoch 176/200
# Learning rate:  1e-06
#  - 112s - loss: 0.1700 - acc: 0.9836 - val_loss: 0.4407 - val_acc: 0.9181
#
# Epoch 00176: val_acc did not improve from 0.91870
# Epoch 177/200
# Learning rate:  1e-06
#  - 110s - loss: 0.1686 - acc: 0.9841 - val_loss: 0.4428 - val_acc: 0.9178
#
# Epoch 00177: val_acc did not improve from 0.91870
# Epoch 178/200
# Learning rate:  1e-06
#  - 110s - loss: 0.1686 - acc: 0.9848 - val_loss: 0.4405 - val_acc: 0.9177
#
# Epoch 00178: val_acc did not improve from 0.91870
# Epoch 179/200
# Learning rate:  1e-06
#  - 110s - loss: 0.1702 - acc: 0.9838 - val_loss: 0.4415 - val_acc: 0.9178
#
# Epoch 00179: val_acc did not improve from 0.91870
# Epoch 180/200
# Learning rate:  1e-06
#  - 113s - loss: 0.1681 - acc: 0.9845 - val_loss: 0.4412 - val_acc: 0.9176
#
# Epoch 00180: val_acc did not improve from 0.91870
# Epoch 181/200
# Learning rate:  1e-06
#  - 114s - loss: 0.1693 - acc: 0.9840 - val_loss: 0.4425 - val_acc: 0.9180
#
# Epoch 00181: val_acc did not improve from 0.91870
# Epoch 182/200
# Learning rate:  5e-07
#  - 113s - loss: 0.1670 - acc: 0.9845 - val_loss: 0.4405 - val_acc: 0.9175
#
# Epoch 00182: val_acc did not improve from 0.91870
# Epoch 183/200
# Learning rate:  5e-07
#  - 114s - loss: 0.1700 - acc: 0.9834 - val_loss: 0.4414 - val_acc: 0.9175
#
# Epoch 00183: val_acc did not improve from 0.91870
# Epoch 184/200
# Learning rate:  5e-07
#  - 113s - loss: 0.1703 - acc: 0.9833 - val_loss: 0.4428 - val_acc: 0.9178
#
# Epoch 00184: val_acc did not improve from 0.91870
# Epoch 185/200
# Learning rate:  5e-07
#  - 116s - loss: 0.1678 - acc: 0.9842 - val_loss: 0.4416 - val_acc: 0.9180
#
# Epoch 00185: val_acc did not improve from 0.91870
# Epoch 186/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1682 - acc: 0.9839 - val_loss: 0.4424 - val_acc: 0.9170
#
# Epoch 00186: val_acc did not improve from 0.91870
# Epoch 187/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1692 - acc: 0.9842 - val_loss: 0.4408 - val_acc: 0.9180
#
# Epoch 00187: val_acc did not improve from 0.91870
# Epoch 188/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1682 - acc: 0.9843 - val_loss: 0.4400 - val_acc: 0.9180
#
# Epoch 00188: val_acc did not improve from 0.91870
# Epoch 189/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1683 - acc: 0.9843 - val_loss: 0.4413 - val_acc: 0.9174
#
# Epoch 00189: val_acc did not improve from 0.91870
# Epoch 190/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1677 - acc: 0.9848 - val_loss: 0.4405 - val_acc: 0.9180
#
# Epoch 00190: val_acc did not improve from 0.91870
# Epoch 191/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1692 - acc: 0.9839 - val_loss: 0.4408 - val_acc: 0.9176
#
# Epoch 00191: val_acc did not improve from 0.91870
# Epoch 192/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1697 - acc: 0.9836 - val_loss: 0.4425 - val_acc: 0.9176
#
# Epoch 00192: val_acc did not improve from 0.91870
# Epoch 193/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1675 - acc: 0.9850 - val_loss: 0.4418 - val_acc: 0.9172
#
# Epoch 00193: val_acc did not improve from 0.91870
# Epoch 194/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1689 - acc: 0.9838 - val_loss: 0.4421 - val_acc: 0.9170
#
# Epoch 00194: val_acc did not improve from 0.91870
# Epoch 195/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1692 - acc: 0.9835 - val_loss: 0.4429 - val_acc: 0.9173
#
# Epoch 00195: val_acc did not improve from 0.91870
# Epoch 196/200
# Learning rate:  5e-07
#  - 116s - loss: 0.1690 - acc: 0.9839 - val_loss: 0.4434 - val_acc: 0.9172
#
# Epoch 00196: val_acc did not improve from 0.91870
# Epoch 197/200
# Learning rate:  5e-07
#  - 116s - loss: 0.1695 - acc: 0.9835 - val_loss: 0.4440 - val_acc: 0.9174
#
# Epoch 00197: val_acc did not improve from 0.91870
# Epoch 198/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1679 - acc: 0.9847 - val_loss: 0.4431 - val_acc: 0.9170
#
# Epoch 00198: val_acc did not improve from 0.91870
# Epoch 199/200
# Learning rate:  5e-07
#  - 115s - loss: 0.1706 - acc: 0.9830 - val_loss: 0.4404 - val_acc: 0.9180
#
# Epoch 00199: val_acc did not improve from 0.91870
# Epoch 200/200
# Learning rate:  5e-07
#  - 116s - loss: 0.1683 - acc: 0.9843 - val_loss: 0.4421 - val_acc: 0.9174
#
# Epoch 00200: val_acc did not improve from 0.91870
# 10000/10000 [==============================] - 5s 483us/step
# Test output: [0.44213177189826963, 0.9174]

# %%
model.save_weights('/content/gdrive/My Drive/colab/weights/cifar10_noshare_boost_oct16.h5')

# %% [markdown]
# Done

# %%
1+2
# Out:
# 3
