# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
"""Trains a ResNet on the CIFAR10 dataset.

ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf

ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf
"""

from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
from keras.callbacks import Callback

import numpy as np
import pandas as pd
from datetime import datetime
import time
import os

from keras.constraints import Constraint
from keras import initializers, layers
from keras.layers import Lambda

class ShrinkageConstraint(Constraint):
    def __init__(self, axis=0):
        self.axis = axis    
    
    def __call__(self, w):
        # apply unitnorm
        #w = w / (K.epsilon() + K.sqrt(K.sum(K.square(w),
        #                                    axis=self.axis,
        #                                    keepdims=True)))
        
        # apply non negative
        w *= K.cast(K.greater_equal(w, 0.), K.floatx())
        # apply max value to be 1
        w *= K.cast(K.less_equal(w, 1.), K.floatx())
        return w


class ShrinkageFactor(layers.Layer):
    """
    This is the sigma object in the algorithm 1 by Beygelzimer (Online Gradient Boosting)
    """
    def __init__(self, step_size, is_trainable=True, **kwargs):
        self.step_size = step_size
        self.is_trainable = is_trainable
        super(ShrinkageFactor, self).__init__(**kwargs)
    
    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.W = self.add_weight(name='highway', 
                                 shape=(1, 1),
                                 initializer=initializers.Zeros(),
                                 constraint=ShrinkageConstraint(),
                                 trainable=self.is_trainable,
                                 regularizer=l2(0.01))
        super(ShrinkageFactor, self).build(input_shape)  # Be sure to call this at the end
    
    def call(self, x):
        return (1-self.step_size*self.W)*x
    
    def compute_output_shape(self, input_shape):
        if isinstance(input_shape, list):
            return input_shape[0]
        return input_shape

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
depth = n * 6 + 2 # n=3 --> 20, n=5 --> 32, n=7 --> 44, n=9 --> 56

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


class TimingCallback(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        # write stuff to disc here...
        self.times.append(time.time() - self.epoch_time_start)

def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 stack=0, 
                 res_block="placeholder",
                 train_shrinkage_only=False):
    """2D Convolution-Batch Normalization-Activation stack builder
    
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
        
        stack (int): stack number for layer naming purposes
        res_block (string): name of the res_block for naming purposes
    
    # Returns
        x (tensor): tensor as input to the next layer
    """
    if train_shrinkage_only:
        trainable=False
    else:
        trainable=True
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4),
                  name=f"resnet_{stack}_{res_block}",
                  trainable=trainable
                  )
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization(name=f"bn_{stack}_{res_block}", trainable=trainable)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization(f"bn_{stack}_{res_block}", trainable=trainable)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_block(x, stack, res_block, num_filters, boost=True, train_shrinkage_only=False):
    strides = 1
    if stack > 0 and res_block == 0:  # first layer but not first stack
        strides = 2  # downsample
    y = resnet_layer(inputs=x,
                     num_filters=num_filters,
                     strides=strides,
                     stack=stack,
                     res_block=f"{res_block}a",
                     train_shrinkage_only=train_shrinkage_only)
    y = resnet_layer(inputs=y,
                     num_filters=num_filters,
                     activation=None,
                     stack=stack,
                     res_block=f"{res_block}b",
                     train_shrinkage_only=train_shrinkage_only)
    if stack > 0 and res_block == 0:  # first layer but not first stack
        # linear projection residual shortcut connection to match
        # changed dims
        x = resnet_layer(inputs=x,
                         num_filters=num_filters,
                         kernel_size=1,
                         strides=strides,
                         activation=None,
                         batch_normalization=False,
                         stack=stack,
                         res_block=f"{res_block}c",
                         train_shrinkage_only=train_shrinkage_only)
    
    if boost:
        step_size = 1.0
        y = ShrinkageFactor(step_size, is_trainable=True, name=f"shrinkage_{stack}_{res_block}")(y)
        x = Lambda(lambda x: x * step_size, name=f"shrinkage_lambda_{stack}_{res_block}")(x)
    
    x = keras.layers.add([x, y], name=f"add_{stack}_{res_block}")
    x = Activation('relu')(x)
    return x
# Out:
# Using TensorFlow backend.
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# model = resnet_v1(input_shape=input_shape, depth=depth)
# we shall hardcode the model...with num_res_blocks=3

num_filters = 16

inputs = Input(shape=input_shape)
x = resnet_layer(inputs=inputs, res_block='preprocessing')

block0_0 = resnet_block(x, 0, 0, num_filters)
block0_1 = resnet_block(block0_0, 0, 1, num_filters)
block0_2 = resnet_block(block0_1, 0, 2, num_filters)

block1_0 = resnet_block(block0_2, 1, 0, num_filters*2)
block1_1 = resnet_block(block1_0, 1, 1, num_filters*2)
block1_2 = resnet_block(block1_1, 1, 2, num_filters*2)

block2_0 = resnet_block(block1_2, 2, 0, num_filters*4)
block2_1 = resnet_block(block2_0, 2, 1, num_filters*4)
block2_2 = resnet_block(block2_1, 2, 2, num_filters*4)

block_output = AveragePooling2D(pool_size=8, name="avg_pool_2_2")(block2_2)
block_output_flatten = Flatten(name="flatten_2_2")(block_output)
#y = Dense(128)(block_output_flatten)

pred_layer_0 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_0')

pred_layer_1 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_1')

pred_layer_2 = Dense(num_classes,
                activation='softmax',
                name='pred_layer_2')
outputs = pred_layer_2(block_output_flatten)


# add auxiliary layers...
block0_0_output = AveragePooling2D(pool_size=8, name="avg_pool_0_0")(block0_0)
block0_0_flatten = Flatten(name="flatten_0_0")(block0_0_output)
#block0_0_y = Dense(128)(block0_0_flatten)
block0_0_outputs = pred_layer_0(block0_0_flatten)

block0_1_output = AveragePooling2D(pool_size=8, name='avg_pool_0_1')(block0_1)
block0_1_flatten = Flatten(name="flatten_0_1")(block0_1_output)
#block0_1_y = Dense(128)(block0_1_flatten)
block0_1_outputs = pred_layer_0(block0_1_flatten)


block0_2_output = AveragePooling2D(pool_size=8, name="avg_pool_0_2")(block0_2)
block0_2_flatten = Flatten(name="flatten_0_2")(block0_2_output)
#block0_2_y = Dense(128)(block0_2_flatten)
block0_2_outputs = pred_layer_0(block0_2_flatten)


block1_0_output = AveragePooling2D(pool_size=8, name="avg_pool_1_0")(block1_0)
block1_0_flatten = Flatten(name="flatten_1_0")(block1_0_output)
#block1_0_y = Dense(128)(block1_0_flatten)
block1_0_outputs = pred_layer_1(block1_0_flatten)


block1_1_output = AveragePooling2D(pool_size=8, name="avg_pool_1_1")(block1_1)
block1_1_flatten = Flatten(name="flatten_1_1")(block1_1_output)
#block1_1_y = Dense(128)(block1_1_flatten)
block1_1_outputs = pred_layer_1(block1_1_flatten)


block1_2_output = AveragePooling2D(pool_size=8, name="avg_pool_1_2")(block1_2)
block1_2_flatten = Flatten(name="flatten_1_2")(block1_2_output)
#block1_2_y = Dense(128)(block1_2_flatten)
block1_2_outputs = pred_layer_1(block1_2_flatten)


block2_0_output = AveragePooling2D(pool_size=8, name='avg_pool_2_0')(block2_0)
block2_0_flatten = Flatten(name="flatten_2_0")(block2_0_output)
#block2_0_y = Dense(128)(block2_0_flatten)
block2_0_outputs = pred_layer_2(block2_0_flatten)


block2_1_output = AveragePooling2D(pool_size=8, name="avg_pool_2_1")(block2_1)
block2_1_flatten = Flatten(name="flatten_2_1")(block2_1_output)
#block2_1_y = Dense(128)(block2_1_flatten)
block2_1_outputs = pred_layer_2(block2_1_flatten)


# block2_2_output = AveragePooling2D(pool_size=4)(block2_2)
# block2_2_flatten = Flatten()(block2_2_output)
# block2_2_y = Dense(128)(block2_2_flatten)
# block2_2_outputs = pred_layer(block2_2_y)

model = Model(inputs=[inputs], outputs=[outputs, block0_0_outputs, block0_1_outputs, block0_2_outputs, block1_0_outputs, block1_1_outputs, block1_2_outputs, block2_0_outputs, block2_1_outputs])
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
save_dir = "/content/gdrive/My Drive/colab/weights/" 
model_name = 'boost_cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name) 

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_pred_layer_2_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

time_cb = TimingCallback()

callbacks = [checkpoint, lr_reducer, lr_scheduler, time_cb]

print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)

# Compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

def data_gen(gen, x, y1, y2, y3, y4, y5, y6, y7, y8, y9):
    gen = gen.flow(x, y1, seed=7, batch_size=batch_size)
    while True:
        X = gen.next()
        #Assert arrays are equal - this was for peace of mind, but slows down training
        #np.testing.assert_array_equal(X1i[0],X2i[0])
        yield X[0], [X[1], X[1], X[1], X[1], X[1], X[1], X[1], X[1], X[1]]
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# resnet_0_preprocessing (Conv2D) (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# bn_0_preprocessing (BatchNormal (None, 32, 32, 16)   64          resnet_0_preprocessing[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           bn_0_preprocessing[0][0]
# __________________________________________________________________________________________________
# resnet_0_0a (Conv2D)            (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# bn_0_0a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_0a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           bn_0_0a[0][0]
# __________________________________________________________________________________________________
# resnet_0_0b (Conv2D)            (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# bn_0_0b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_0b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_0_0 (Lambda)   (None, 32, 32, 16)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_0 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_0b[0][0]
# __________________________________________________________________________________________________
# add_0_0 (Add)                   (None, 32, 32, 16)   0           shrinkage_lambda_0_0[0][0]
#                                                                  shrinkage_0_0[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_0_0[0][0]
# __________________________________________________________________________________________________
# resnet_0_1a (Conv2D)            (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# bn_0_1a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_1a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           bn_0_1a[0][0]
# __________________________________________________________________________________________________
# resnet_0_1b (Conv2D)            (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# bn_0_1b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_0_1 (Lambda)   (None, 32, 32, 16)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_1 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_1b[0][0]
# __________________________________________________________________________________________________
# add_0_1 (Add)                   (None, 32, 32, 16)   0           shrinkage_lambda_0_1[0][0]
#                                                                  shrinkage_0_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_0_1[0][0]
# __________________________________________________________________________________________________
# resnet_0_2a (Conv2D)            (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# bn_0_2a (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           bn_0_2a[0][0]
# __________________________________________________________________________________________________
# resnet_0_2b (Conv2D)            (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# bn_0_2b (BatchNormalization)    (None, 32, 32, 16)   64          resnet_0_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_0_2 (Lambda)   (None, 32, 32, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# shrinkage_0_2 (ShrinkageFactor) (None, 32, 32, 16)   1           bn_0_2b[0][0]
# __________________________________________________________________________________________________
# add_0_2 (Add)                   (None, 32, 32, 16)   0           shrinkage_lambda_0_2[0][0]
#                                                                  shrinkage_0_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_0_2[0][0]
# __________________________________________________________________________________________________
# resnet_1_0a (Conv2D)            (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# bn_1_0a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_0a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           bn_1_0a[0][0]
# __________________________________________________________________________________________________
# resnet_1_0b (Conv2D)            (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# resnet_1_0c (Conv2D)            (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# bn_1_0b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_0b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_1_0 (Lambda)   (None, 16, 16, 32)   0           resnet_1_0c[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_0 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_0b[0][0]
# __________________________________________________________________________________________________
# add_1_0 (Add)                   (None, 16, 16, 32)   0           shrinkage_lambda_1_0[0][0]
#                                                                  shrinkage_1_0[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_1_0[0][0]
# __________________________________________________________________________________________________
# resnet_1_1a (Conv2D)            (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# bn_1_1a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_1a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           bn_1_1a[0][0]
# __________________________________________________________________________________________________
# resnet_1_1b (Conv2D)            (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# bn_1_1b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_1_1 (Lambda)   (None, 16, 16, 32)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_1 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_1b[0][0]
# __________________________________________________________________________________________________
# add_1_1 (Add)                   (None, 16, 16, 32)   0           shrinkage_lambda_1_1[0][0]
#                                                                  shrinkage_1_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_1_1[0][0]
# __________________________________________________________________________________________________
# resnet_1_2a (Conv2D)            (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# bn_1_2a (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           bn_1_2a[0][0]
# __________________________________________________________________________________________________
# resnet_1_2b (Conv2D)            (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# bn_1_2b (BatchNormalization)    (None, 16, 16, 32)   128         resnet_1_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_1_2 (Lambda)   (None, 16, 16, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# shrinkage_1_2 (ShrinkageFactor) (None, 16, 16, 32)   1           bn_1_2b[0][0]
# __________________________________________________________________________________________________
# add_1_2 (Add)                   (None, 16, 16, 32)   0           shrinkage_lambda_1_2[0][0]
#                                                                  shrinkage_1_2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_1_2[0][0]
# __________________________________________________________________________________________________
# resnet_2_0a (Conv2D)            (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# bn_2_0a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_0a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           bn_2_0a[0][0]
# __________________________________________________________________________________________________
# resnet_2_0b (Conv2D)            (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# resnet_2_0c (Conv2D)            (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# bn_2_0b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_0b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_2_0 (Lambda)   (None, 8, 8, 64)     0           resnet_2_0c[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_0 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_0b[0][0]
# __________________________________________________________________________________________________
# add_2_0 (Add)                   (None, 8, 8, 64)     0           shrinkage_lambda_2_0[0][0]
#                                                                  shrinkage_2_0[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_2_0[0][0]
# __________________________________________________________________________________________________
# resnet_2_1a (Conv2D)            (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# bn_2_1a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_1a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           bn_2_1a[0][0]
# __________________________________________________________________________________________________
# resnet_2_1b (Conv2D)            (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# bn_2_1b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_1b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_2_1 (Lambda)   (None, 8, 8, 64)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_1 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_1b[0][0]
# __________________________________________________________________________________________________
# add_2_1 (Add)                   (None, 8, 8, 64)     0           shrinkage_lambda_2_1[0][0]
#                                                                  shrinkage_2_1[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_2_1[0][0]
# __________________________________________________________________________________________________
# resnet_2_2a (Conv2D)            (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# bn_2_2a (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_2a[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           bn_2_2a[0][0]
# __________________________________________________________________________________________________
# resnet_2_2b (Conv2D)            (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# bn_2_2b (BatchNormalization)    (None, 8, 8, 64)     256         resnet_2_2b[0][0]
# __________________________________________________________________________________________________
# shrinkage_lambda_2_2 (Lambda)   (None, 8, 8, 64)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# shrinkage_2_2 (ShrinkageFactor) (None, 8, 8, 64)     1           bn_2_2b[0][0]
# __________________________________________________________________________________________________
# add_2_2 (Add)                   (None, 8, 8, 64)     0           shrinkage_lambda_2_2[0][0]
#                                                                  shrinkage_2_2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_2_2[0][0]
# __________________________________________________________________________________________________
# avg_pool_2_2 (AveragePooling2D) (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# avg_pool_0_0 (AveragePooling2D) (None, 4, 4, 16)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# avg_pool_0_1 (AveragePooling2D) (None, 4, 4, 16)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# avg_pool_0_2 (AveragePooling2D) (None, 4, 4, 16)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# avg_pool_1_0 (AveragePooling2D) (None, 2, 2, 32)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# avg_pool_1_1 (AveragePooling2D) (None, 2, 2, 32)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# avg_pool_1_2 (AveragePooling2D) (None, 2, 2, 32)     0           activation_13[0][0]
# __________________________________________________________________________________________________
# avg_pool_2_0 (AveragePooling2D) (None, 1, 1, 64)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# avg_pool_2_1 (AveragePooling2D) (None, 1, 1, 64)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_2_2 (Flatten)           (None, 64)           0           avg_pool_2_2[0][0]
# __________________________________________________________________________________________________
# flatten_0_0 (Flatten)           (None, 256)          0           avg_pool_0_0[0][0]
# __________________________________________________________________________________________________
# flatten_0_1 (Flatten)           (None, 256)          0           avg_pool_0_1[0][0]
# __________________________________________________________________________________________________
# flatten_0_2 (Flatten)           (None, 256)          0           avg_pool_0_2[0][0]
# __________________________________________________________________________________________________
# flatten_1_0 (Flatten)           (None, 128)          0           avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# flatten_1_1 (Flatten)           (None, 128)          0           avg_pool_1_1[0][0]
# __________________________________________________________________________________________________
# flatten_1_2 (Flatten)           (None, 128)          0           avg_pool_1_2[0][0]
# __________________________________________________________________________________________________
# flatten_2_0 (Flatten)           (None, 64)           0           avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# flatten_2_1 (Flatten)           (None, 64)           0           avg_pool_2_1[0][0]
# __________________________________________________________________________________________________
# pred_layer_2 (Dense)            (None, 10)           650         flatten_2_2[0][0]
#                                                                  flatten_2_0[0][0]
#                                                                  flatten_2_1[0][0]
# __________________________________________________________________________________________________
# pred_layer_0 (Dense)            (None, 10)           2570        flatten_0_0[0][0]
#                                                                  flatten_0_1[0][0]
#                                                                  flatten_0_2[0][0]
# __________________________________________________________________________________________________
# pred_layer_1 (Dense)            (None, 10)           1290        flatten_1_0[0][0]
#                                                                  flatten_1_1[0][0]
#                                                                  flatten_1_2[0][0]
# ==================================================================================================
# Total params: 278,311
# Trainable params: 276,935
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# Using real-time data augmentation.

# %%
# Fit the model on the batches generated by datagen.flow().
hist = model.fit_generator(data_gen(datagen, x_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train),
                    validation_data=(x_test, [y_test, y_test, y_test, y_test, y_test, y_test, y_test, y_test, y_test]),
                    steps_per_epoch=1600,
                    epochs=epochs, verbose=2, workers=10,
                    callbacks=callbacks)
hist_df = pd.DataFrame(hist.history)
hist_df['times'] = time_cb.times[-hist_df.shape[0]:]
hist_df.to_csv('/content/gdrive/My Drive/colab/weights/training_history_resnetv1{}.csv'.format(datetime.now().strftime('%Y-%m-%d_%H-%M-%S')), index=True)

# Score trained model.
scores = model.evaluate(x_test, [y_test, y_test, y_test, y_test, y_test, y_test, y_test, y_test, y_test], verbose=1)
print('Test output:', scores)
# Out:
# Epoch 1/200
# Learning rate:  0.001
#  - 174s - loss: 13.9424 - pred_layer_2_loss: 1.4543 - pred_layer_0_loss: 1.5857 - pred_layer_1_loss: 1.4585 - pred_layer_2_acc: 0.4765 - pred_layer_0_acc: 0.3975 - pred_layer_0_acc_1: 0.4206 - pred_layer_0_acc_2: 0.4260 - pred_layer_1_acc: 0.4248 - pred_layer_1_acc_1: 0.4608 - pred_layer_1_acc_2: 0.4691 - pred_layer_2_acc_1: 0.4585 - pred_layer_2_acc_2: 0.4771 - val_loss: 12.4669 - val_pred_layer_2_loss: 1.2837 - val_pred_layer_0_loss: 1.4881 - val_pred_layer_1_loss: 1.2756 - val_pred_layer_2_acc: 0.5511 - val_pred_layer_0_acc: 0.4733 - val_pred_layer_0_acc_1: 0.4773 - val_pred_layer_0_acc_2: 0.4762 - val_pred_layer_1_acc: 0.5040 - val_pred_layer_1_acc_1: 0.5359 - val_pred_layer_1_acc_2: 0.5492 - val_pred_layer_2_acc_1: 0.5314 - val_pred_layer_2_acc_2: 0.5474
#
# Epoch 00001: val_pred_layer_2_acc improved from -inf to 0.55110, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
#  - 167s - loss: 10.9609 - pred_layer_2_loss: 1.0787 - pred_layer_0_loss: 1.2661 - pred_layer_1_loss: 1.1073 - pred_layer_2_acc: 0.6179 - pred_layer_0_acc: 0.4988 - pred_layer_0_acc_1: 0.5371 - pred_layer_0_acc_2: 0.5495 - pred_layer_1_acc: 0.5529 - pred_layer_1_acc_1: 0.5953 - pred_layer_1_acc_2: 0.6074 - pred_layer_2_acc_1: 0.5983 - pred_layer_2_acc_2: 0.6167 - val_loss: 11.2246 - val_pred_layer_2_loss: 1.1450 - val_pred_layer_0_loss: 1.3475 - val_pred_layer_1_loss: 1.1266 - val_pred_layer_2_acc: 0.6044 - val_pred_layer_0_acc: 0.5422 - val_pred_layer_0_acc_1: 0.5369 - val_pred_layer_0_acc_2: 0.5344 - val_pred_layer_1_acc: 0.5293 - val_pred_layer_1_acc_1: 0.5761 - val_pred_layer_1_acc_2: 0.6062 - val_pred_layer_2_acc_1: 0.5870 - val_pred_layer_2_acc_2: 0.6061
#
# Epoch 00002: val_pred_layer_2_acc improved from 0.55110 to 0.60440, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
#  - 167s - loss: 9.7519 - pred_layer_2_loss: 0.9118 - pred_layer_0_loss: 1.1513 - pred_layer_1_loss: 0.9668 - pred_layer_2_acc: 0.6806 - pred_layer_0_acc: 0.5315 - pred_layer_0_acc_1: 0.5793 - pred_layer_0_acc_2: 0.5912 - pred_layer_1_acc: 0.5934 - pred_layer_1_acc_1: 0.6422 - pred_layer_1_acc_2: 0.6575 - pred_layer_2_acc_1: 0.6583 - pred_layer_2_acc_2: 0.6793 - val_loss: 11.7542 - val_pred_layer_2_loss: 1.2381 - val_pred_layer_0_loss: 1.2765 - val_pred_layer_1_loss: 1.1859 - val_pred_layer_2_acc: 0.5998 - val_pred_layer_0_acc: 0.4953 - val_pred_layer_0_acc_1: 0.5515 - val_pred_layer_0_acc_2: 0.5657 - val_pred_layer_1_acc: 0.5190 - val_pred_layer_1_acc_1: 0.5883 - val_pred_layer_1_acc_2: 0.6067 - val_pred_layer_2_acc_1: 0.5904 - val_pred_layer_2_acc_2: 0.6025
#
# Epoch 00003: val_pred_layer_2_acc did not improve from 0.60440
# Epoch 4/200
# Learning rate:  0.001
#  - 169s - loss: 9.0938 - pred_layer_2_loss: 0.8233 - pred_layer_0_loss: 1.0900 - pred_layer_1_loss: 0.8921 - pred_layer_2_acc: 0.7109 - pred_layer_0_acc: 0.5529 - pred_layer_0_acc_1: 0.6008 - pred_layer_0_acc_2: 0.6125 - pred_layer_1_acc: 0.6201 - pred_layer_1_acc_1: 0.6730 - pred_layer_1_acc_2: 0.6879 - pred_layer_2_acc_1: 0.6917 - pred_layer_2_acc_2: 0.7103 - val_loss: 9.9929 - val_pred_layer_2_loss: 1.0191 - val_pred_layer_0_loss: 1.1832 - val_pred_layer_1_loss: 1.0286 - val_pred_layer_2_acc: 0.6735 - val_pred_layer_0_acc: 0.5770 - val_pred_layer_0_acc_1: 0.6012 - val_pred_layer_0_acc_2: 0.5979 - val_pred_layer_1_acc: 0.6018 - val_pred_layer_1_acc_1: 0.6549 - val_pred_layer_1_acc_2: 0.6601 - val_pred_layer_2_acc_1: 0.6525 - val_pred_layer_2_acc_2: 0.6760
#
# Epoch 00004: val_pred_layer_2_acc improved from 0.60440 to 0.67350, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
#  - 168s - loss: 8.5851 - pred_layer_2_loss: 0.7525 - pred_layer_0_loss: 1.0469 - pred_layer_1_loss: 0.8299 - pred_layer_2_acc: 0.7389 - pred_layer_0_acc: 0.5722 - pred_layer_0_acc_1: 0.6204 - pred_layer_0_acc_2: 0.6296 - pred_layer_1_acc: 0.6392 - pred_layer_1_acc_1: 0.6945 - pred_layer_1_acc_2: 0.7106 - pred_layer_2_acc_1: 0.7210 - pred_layer_2_acc_2: 0.7393 - val_loss: 8.4686 - val_pred_layer_2_loss: 0.7852 - val_pred_layer_0_loss: 1.0148 - val_pred_layer_1_loss: 0.8003 - val_pred_layer_2_acc: 0.7450 - val_pred_layer_0_acc: 0.5984 - val_pred_layer_0_acc_1: 0.6349 - val_pred_layer_0_acc_2: 0.6497 - val_pred_layer_1_acc: 0.6428 - val_pred_layer_1_acc_1: 0.7079 - val_pred_layer_1_acc_2: 0.7265 - val_pred_layer_2_acc_1: 0.7230 - val_pred_layer_2_acc_2: 0.7439
#
# Epoch 00005: val_pred_layer_2_acc improved from 0.67350 to 0.74500, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.005.h5
# Epoch 6/200
# Learning rate:  0.001
#  - 166s - loss: 8.2863 - pred_layer_2_loss: 0.7122 - pred_layer_0_loss: 1.0287 - pred_layer_1_loss: 0.7905 - pred_layer_2_acc: 0.7535 - pred_layer_0_acc: 0.5805 - pred_layer_0_acc_1: 0.6250 - pred_layer_0_acc_2: 0.6365 - pred_layer_1_acc: 0.6520 - pred_layer_1_acc_1: 0.7071 - pred_layer_1_acc_2: 0.7233 - pred_layer_2_acc_1: 0.7380 - pred_layer_2_acc_2: 0.7546 - val_loss: 10.1567 - val_pred_layer_2_loss: 0.9828 - val_pred_layer_0_loss: 1.2403 - val_pred_layer_1_loss: 0.9985 - val_pred_layer_2_acc: 0.6990 - val_pred_layer_0_acc: 0.5572 - val_pred_layer_0_acc_1: 0.5958 - val_pred_layer_0_acc_2: 0.5936 - val_pred_layer_1_acc: 0.5835 - val_pred_layer_1_acc_1: 0.6563 - val_pred_layer_1_acc_2: 0.6878 - val_pred_layer_2_acc_1: 0.6848 - val_pred_layer_2_acc_2: 0.6998
#
# Epoch 00006: val_pred_layer_2_acc did not improve from 0.74500
# Epoch 7/200
# Learning rate:  0.001
#  - 166s - loss: 8.0181 - pred_layer_2_loss: 0.6750 - pred_layer_0_loss: 1.0060 - pred_layer_1_loss: 0.7594 - pred_layer_2_acc: 0.7672 - pred_layer_0_acc: 0.5904 - pred_layer_0_acc_1: 0.6338 - pred_layer_0_acc_2: 0.6449 - pred_layer_1_acc: 0.6629 - pred_layer_1_acc_1: 0.7186 - pred_layer_1_acc_2: 0.7349 - pred_layer_2_acc_1: 0.7525 - pred_layer_2_acc_2: 0.7678 - val_loss: 8.7625 - val_pred_layer_2_loss: 0.9374 - val_pred_layer_0_loss: 0.9714 - val_pred_layer_1_loss: 0.8380 - val_pred_layer_2_acc: 0.7019 - val_pred_layer_0_acc: 0.6186 - val_pred_layer_0_acc_1: 0.6482 - val_pred_layer_0_acc_2: 0.6620 - val_pred_layer_1_acc: 0.6398 - val_pred_layer_1_acc_1: 0.7072 - val_pred_layer_1_acc_2: 0.7175 - val_pred_layer_2_acc_1: 0.6959 - val_pred_layer_2_acc_2: 0.6967
#
# Epoch 00007: val_pred_layer_2_acc did not improve from 0.74500
# Epoch 8/200
# Learning rate:  0.001
 0.7938 - val_pred_layer_0_loss: 1.0492 - val_pred_layer_1_loss: 0.8879 - val_pred_layer_2_acc: 0.7444 - val_pred_layer_0_acc: 0.6045 - val_pred_layer_0_acc_1: 0.6371 - val_pred_layer_0_acc_2: 0.6417 - val_pred_layer_1_acc: 0.6149 - val_pred_layer_1_acc_1: 0.7057 - val_pred_layer_1_acc_2: 0.7103 - val_pred_layer_2_acc_1: 0.7374 - val_pred_layer_2_acc_2: 0.7434
#
# Epoch 00013: val_pred_layer_2_acc did not improve from 0.78420
# Epoch 14/200
# Learning rate:  0.001
#  - 168s - loss: 6.9975 - pred_layer_2_loss: 0.5293 - pred_layer_0_loss: 0.9224 - pred_layer_1_loss: 0.6224 - pred_layer_2_acc: 0.8172 - pred_layer_0_acc: 0.6210 - pred_layer_0_acc_1: 0.6624 - pred_layer_0_acc_2: 0.6757 - pred_layer_1_acc: 0.7067 - pred_layer_1_acc_1: 0.7674 - pred_layer_1_acc_2: 0.7874 - pred_layer_2_acc_1: 0.8057 - pred_layer_2_acc_2: 0.8178 - val_loss: 7.3272 - val_pred_layer_2_loss: 0.6367 - val_pred_layer_0_loss: 0.9080 - val_pred_layer_1_loss: 0.6964 - val_pred_layer_2_acc: 0.7897 - val_pred_layer_0_acc: 0.6466 - val_pred_layer_0_acc_1: 0.6833 - val_pred_layer_0_acc_2: 0.6845 - val_pred_layer_1_acc: 0.6998 - val_pred_layer_1_acc_1: 0.7582 - val_pred_layer_1_acc_2: 0.7730 - val_pred_layer_2_acc_1: 0.7747 - val_pred_layer_2_acc_2: 0.7880
#
# Epoch 00014: val_pred_layer_2_acc improved from 0.78420 to 0.78970, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
#  - 167s - loss: 6.9633 - pred_layer_2_loss: 0.5228 - pred_layer_0_loss: 0.9252 - pred_layer_1_loss: 0.6168 - pred_layer_2_acc: 0.8207 - pred_layer_0_acc: 0.6204 - pred_layer_0_acc_1: 0.6645 - pred_layer_0_acc_2: 0.6759 - pred_layer_1_acc: 0.7120 - pred_layer_1_acc_1: 0.7687 - pred_layer_1_acc_2: 0.7893 - pred_layer_2_acc_1: 0.8094 - pred_layer_2_acc_2: 0.8203 - val_loss: 11.7881 - val_pred_layer_2_loss: 1.1401 - val_pred_layer_0_loss: 1.3811 - val_pred_layer_1_loss: 1.2257 - val_pred_layer_2_acc: 0.6800 - val_pred_layer_0_acc: 0.5508 - val_pred_layer_0_acc_1: 0.5628 - val_pred_layer_0_acc_2: 0.5650 - val_pred_layer_1_acc: 0.5613 - val_pred_layer_1_acc_1: 0.6206 - val_pred_layer_1_acc_2: 0.6481 - val_pred_layer_2_acc_1: 0.6310 - val_pred_layer_2_acc_2: 0.6800
#
# Epoch 00015: val_pred_layer_2_acc did not improve from 0.78970
# Epoch 16/200
# Learning rate:  0.001
#  - 168s - loss: 6.8955 - pred_layer_2_loss: 0.5162 - pred_layer_0_loss: 0.9154 - pred_layer_1_loss: 0.6074 - pred_layer_2_acc: 0.8223 - pred_layer_0_acc: 0.6250 - pred_layer_0_acc_1: 0.6698 - pred_layer_0_acc_2: 0.6814 - pred_layer_1_acc: 0.7135 - pred_layer_1_acc_1: 0.7712 - pred_layer_1_acc_2: 0.7904 - pred_layer_2_acc_1: 0.8099 - pred_layer_2_acc_2: 0.8224 - val_loss: 7.9475 - val_pred_layer_2_loss: 0.7476 - val_pred_layer_0_loss: 0.9684 - val_pred_layer_1_loss: 0.7173 - val_pred_layer_2_acc: 0.7667 - val_pred_layer_0_acc: 0.6243 - val_pred_layer_0_acc_1: 0.6711 - val_pred_layer_0_acc_2: 0.6647 - val_pred_layer_1_acc: 0.6632 - val_pred_layer_1_acc_1: 0.7468 - val_pred_layer_1_acc_2: 0.7661 - val_pred_layer_2_acc_1: 0.7562 - val_pred_layer_2_acc_2: 0.7650
#
# Epoch 00016: val_pred_layer_2_acc did not improve from 0.78970
# Epoch 17/200
# Learning rate:  0.001
#  - 167s - loss: 6.8125 - pred_layer_2_loss: 0.5052 - pred_layer_0_loss: 0.9075 - pred_layer_1_loss: 0.5946 - pred_layer_2_acc: 0.8244 - pred_layer_0_acc: 0.6240 - pred_layer_0_acc_1: 0.6686 - pred_layer_0_acc_2: 0.6796 - pred_layer_1_acc: 0.7159 - pred_layer_1_acc_1: 0.7748 - pred_layer_1_acc_2: 0.7948 - pred_layer_2_acc_1: 0.8131 - pred_layer_2_acc_2: 0.8238 - val_loss: 7.4895 - val_pred_layer_2_loss: 0.6504 - val_pred_layer_0_loss: 0.9121 - val_pred_layer_1_loss: 0.6756 - val_pred_layer_2_acc: 0.7864 - val_pred_layer_0_acc: 0.6433 - val_pred_layer_0_acc_1: 0.6545 - val_pred_layer_0_acc_2: 0.6778 - val_pred_layer_1_acc: 0.6740 - val_pred_layer_1_acc_1: 0.7563 - val_pred_layer_1_acc_2: 0.7771 - val_pred_layer_2_acc_1: 0.7778 - val_pred_layer_2_acc_2: 0.7850
#
# Epoch 00017: val_pred_layer_2_acc did not improve from 0.78970
# Epoch 18/200
# Learning rate:  0.001
#  - 168s - loss: 6.7083 - pred_layer_2_loss: 0.4887 - pred_layer_0_loss: 0.8964 - pred_layer_1_loss: 0.5832 - pred_layer_2_acc: 0.8323 - pred_layer_0_acc: 0.6246 - pred_layer_0_acc_1: 0.6755 - pred_layer_0_acc_2: 0.6871 - pred_layer_1_acc: 0.7235 - pred_layer_1_acc_1: 0.7803 - pred_layer_1_acc_2: 0.7998 - pred_layer_2_acc_1: 0.8200 - pred_layer_2_acc_2: 0.8324 - val_loss: 7.8044 - val_pred_layer_2_loss: 0.6634 - val_pred_layer_0_loss: 0.9359 - val_pred_layer_1_loss: 0.7263 - val_pred_layer_2_acc: 0.7884 - val_pred_layer_0_acc: 0.6213 - val_pred_layer_0_acc_1: 0.6592 - val_pred_layer_0_acc_2: 0.6801 - val_pred_layer_1_acc: 0.6728 - val_pred_layer_1_acc_1: 0.7309 - val_pred_layer_1_acc_2: 0.7687 - val_pred_layer_2_acc_1: 0.7763 - val_pred_layer_2_acc_2: 0.7865
#
# Epoch 00018: val_pred_layer_2_acc did not improve from 0.78970
val_pred_layer_2_acc did not improve from 0.82070
# Epoch 33/200
# Learning rate:  0.001
#  - 168s - loss: 6.1289 - pred_layer_2_loss: 0.4040 - pred_layer_0_loss: 0.8376 - pred_layer_1_loss: 0.5037 - pred_layer_2_acc: 0.8606 - pred_layer_0_acc: 0.6415 - pred_layer_0_acc_1: 0.6905 - pred_layer_0_acc_2: 0.7062 - pred_layer_1_acc: 0.7497 - pred_layer_1_acc_1: 0.8086 - pred_layer_1_acc_2: 0.8279 - pred_layer_2_acc_1: 0.8487 - pred_layer_2_acc_2: 0.8606 - val_loss: 7.4709 - val_pred_layer_2_loss: 0.6378 - val_pred_layer_0_loss: 0.8837 - val_pred_layer_1_loss: 0.6791 - val_pred_layer_2_acc: 0.8011 - val_pred_layer_0_acc: 0.6445 - val_pred_layer_0_acc_1: 0.6593 - val_pred_layer_0_acc_2: 0.6902 - val_pred_layer_1_acc: 0.6999 - val_pred_layer_1_acc_1: 0.7626 - val_pred_layer_1_acc_2: 0.7865 - val_pred_layer_2_acc_1: 0.7858 - val_pred_layer_2_acc_2: 0.7995
#
# Epoch 00033: val_pred_layer_2_acc did not improve from 0.82070
# Epoch 34/200
# Learning rate:  0.001
#  - 168s - loss: 6.0813 - pred_layer_2_loss: 0.3983 - pred_layer_0_loss: 0.8321 - pred_layer_1_loss: 0.4943 - pred_layer_2_acc: 0.8624 - pred_layer_0_acc: 0.6429 - pred_layer_0_acc_1: 0.6928 - pred_layer_0_acc_2: 0.7081 - pred_layer_1_acc: 0.7510 - pred_layer_1_acc_1: 0.8088 - pred_layer_1_acc_2: 0.8300 - pred_layer_2_acc_1: 0.8499 - pred_layer_2_acc_2: 0.8620 - val_loss: 7.3447 - val_pred_layer_2_loss: 0.6136 - val_pred_layer_0_loss: 0.9008 - val_pred_layer_1_loss: 0.6727 - val_pred_layer_2_acc: 0.8088 - val_pred_layer_0_acc: 0.6545 - val_pred_layer_0_acc_1: 0.6765 - val_pred_layer_0_acc_2: 0.6910 - val_pred_layer_1_acc: 0.7131 - val_pred_layer_1_acc_1: 0.7698 - val_pred_layer_1_acc_2: 0.7883 - val_pred_layer_2_acc_1: 0.7939 - val_pred_layer_2_acc_2: 0.8098
#
# Epoch 00034: val_pred_layer_2_acc did not improve from 0.82070
# Epoch 35/200
# Learning rate:  0.001
#  - 168s - loss: 6.0839 - pred_layer_2_loss: 0.3983 - pred_layer_0_loss: 0.8316 - pred_layer_1_loss: 0.4969 - pred_layer_2_acc: 0.8599 - pred_layer_0_acc: 0.6449 - pred_layer_0_acc_1: 0.6946 - pred_layer_0_acc_2: 0.7082 - pred_layer_1_acc: 0.7524 - pred_layer_1_acc_1: 0.8103 - pred_layer_1_acc_2: 0.8290 - pred_layer_2_acc_1: 0.8500 - pred_layer_2_acc_2: 0.8594 - val_loss: 6.5606 - val_pred_layer_2_loss: 0.5374 - val_pred_layer_0_loss: 0.8218 - val_pred_layer_1_loss: 0.5769 - val_pred_layer_2_acc: 0.8284 - val_pred_layer_0_acc: 0.6701 - val_pred_layer_0_acc_1: 0.7047 - val_pred_layer_0_acc_2: 0.7173 - val_pred_layer_1_acc: 0.7401 - val_pred_layer_1_acc_1: 0.7931 - val_pred_layer_1_acc_2: 0.8160 - val_pred_layer_2_acc_1: 0.8257 - val_pred_layer_2_acc_2: 0.8272
#
# Epoch 00035: val_pred_layer_2_acc improved from 0.82070 to 0.82840, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.035.h5
# Epoch 36/200
# Learning rate:  0.001
c_2: 0.8646 - val_loss: 7.0351 - val_pred_layer_2_loss: 0.5002 - val_pred_layer_0_loss: 0.9635 - val_pred_layer_1_loss: 0.5663 - val_pred_layer_2_acc: 0.8343 - val_pred_layer_0_acc: 0.6147 - val_pred_layer_0_acc_1: 0.6592 - val_pred_layer_0_acc_2: 0.6736 - val_pred_layer_1_acc: 0.7235 - val_pred_layer_1_acc_1: 0.7950 - val_pred_layer_1_acc_2: 0.8085 - val_pred_layer_2_acc_1: 0.8181 - val_pred_layer_2_acc_2: 0.8350
#
# Epoch 00038: val_pred_layer_2_acc improved from 0.82840 to 0.83430, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.038.h5
# Epoch 39/200
# Learning rate:  0.001
#  - 166s - loss: 5.9695 - pred_layer_2_loss: 0.3811 - pred_layer_0_loss: 0.8207 - pred_layer_1_loss: 0.4814 - pred_layer_2_acc: 0.8676 - pred_layer_0_acc: 0.6476 - pred_layer_0_acc_1: 0.6980 - pred_layer_0_acc_2: 0.7137 - pred_layer_1_acc: 0.7562 - pred_layer_1_acc_1: 0.8138 - pred_layer_1_acc_2: 0.8338 - pred_layer_2_acc_1: 0.8563 - pred_layer_2_acc_2: 0.8676 - val_loss: 7.5178 - val_pred_layer_2_loss: 0.6509 - val_pred_layer_0_loss: 0.8567 - val_pred_layer_1_loss: 0.7459 - val_pred_layer_2_acc: 0.7982 - val_pred_layer_0_acc: 0.6432 - val_pred_layer_0_acc_1: 0.6802 - val_pred_layer_0_acc_2: 0.7021 - val_pred_layer_1_acc: 0.7033 - val_pred_layer_1_acc_1: 0.7613 - val_pred_layer_1_acc_2: 0.7695 - val_pred_layer_2_acc_1: 0.7888 - val_pred_layer_2_acc_2: 0.7993
#
# Epoch 00039: val_pred_layer_2_acc did not improve from 0.83430
# Epoch 40/200
# Learning rate:  0.001
#  - 167s - loss: 5.9996 - pred_layer_2_loss: 0.3845 - pred_layer_0_loss: 0.8245 - pred_layer_1_loss: 0.4823 - pred_layer_2_acc: 0.8661 - pred_layer_0_acc: 0.6461 - pred_layer_0_acc_1: 0.6979 - pred_layer_0_acc_2: 0.7137 - pred_layer_1_acc: 0.7585 - pred_layer_1_acc_1: 0.8151 - pred_layer_1_acc_2: 0.8330 - pred_layer_2_acc_1: 0.8560 - pred_layer_2_acc_2: 0.8663 - val_loss: 6.7418 - val_pred_layer_2_loss: 0.5397 - val_pred_layer_0_loss: 0.8241 - val_pred_layer_1_loss: 0.6113 - val_pred_layer_2_acc: 0.8257 - val_pred_layer_0_acc: 0.6523 - val_pred_layer_0_acc_1: 0.7070 - val_pred_layer_0_acc_2: 0.7159 - val_pred_layer_1_acc: 0.7292 - val_pred_layer_1_acc_1: 0.7833 - val_pred_layer_1_acc_2: 0.8007 - val_pred_layer_2_acc_1: 0.8143 - val_pred_layer_2_acc_2: 0.8239
#
# Epoch 00040: val_pred_layer_2_acc did not improve from 0.83430
# Epoch 41/200
# Learning rate:  0.001
#  - 168s - loss: 5.9326 - pred_layer_2_loss: 0.3772 - pred_layer_0_loss: 0.8171 - pred_layer_1_loss: 0.4734 - pred_layer_2_acc: 0.8691 - pred_layer_0_acc: 0.6480 - pred_layer_0_acc_1: 0.6981 - pred_layer_0_acc_2: 0.7133 - pred_layer_1_acc: 0.7588 - pred_layer_1_acc_1: 0.8153 - pred_layer_1_acc_2: 0.8358 - pred_layer_2_acc_1: 0.8582 - pred_layer_2_acc_2: 0.8689 - val_loss: 6.5121 - val_pred_layer_2_loss: 0.4753 - val_pred_layer_0_loss: 0.8079 - val_pred_layer_1_loss: 0.5919 - val_pred_layer_2_acc: 0.8418 - val_pred_layer_0_acc: 0.6413 - val_pred_layer_0_acc_1: 0.7061 - val_pred_layer_0_acc_2: 0.7208 - val_pred_layer_1_acc: 0.7465 - val_pred_layer_1_acc_1: 0.7852 - val_pred_layer_1_acc_2: 0.8005 - val_pred_layer_2_acc_1: 0.8310 - val_pred_layer_2_acc_2: 0.8416
#
# Epoch 00041: val_pred_layer_2_acc improved from 0.83430 to 0.84180, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.041.h5
# Epoch 42/200
# Learning rate:  0.001
#  - 168s - loss: 5.9331 - pred_layer_2_loss: 0.3763 - pred_layer_0_loss: 0.8163 - pred_layer_1_loss: 0.4738 - pred_layer_2_acc: 0.8702 - pred_layer_0_acc: 0.6495 - pred_layer_0_acc_1: 0.7014 - pred_layer_0_acc_2: 0.7168 - pred_layer_1_acc: 0.7591 - pred_layer_1_acc_1: 0.8162 - pred_layer_1_acc_2: 0.8363 - pred_layer_2_acc_1: 0.8590 - pred_layer_2_acc_2: 0.8703 - val_loss: 6.5012 - val_pred_layer_2_loss: 0.4472 - val_pred_layer_0_loss: 0.8665 - val_pred_layer_1_loss: 0.5922 - val_pred_layer_2_acc: 0.8458 - val_pred_layer_0_acc: 0.6674 - val_pred_layer_0_acc_1: 0.6921 - val_pred_layer_0_acc_2: 0.6993 - val_pred_layer_1_acc: 0.7237 - val_pred_layer_1_acc_1: 0.7900 - val_pred_layer_1_acc_2: 0.8016 - val_pred_layer_2_acc_1: 0.8315 - val_pred_layer_2_acc_2: 0.8465
#
# Epoch 00042: val_pred_layer_2_acc improved from 0.84180 to 0.84580, saving model to /content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.042.h5
# Epoch 43/200
# Learning rate:  0.001
#  - 167s - loss: 5.8817 - pred_layer_2_loss: 0.3702 - pred_layer_0_loss: 0.8126 - pred_layer_1_loss: 0.4676 - pred_layer_2_acc: 0.8711 - pred_layer_0_acc: 0.6494 - pred_layer_0_acc_1: 0.7025 - pred_layer_0_acc_2: 0.7183 - pred_layer_1_acc: 0.7618 - pred_layer_1_acc_1: 0.8210 - pred_layer_1_acc_2: 0.8390 - pred_layer_2_acc_1: 0.8613 - pred_layer_2_acc_2: 0.8712 - val_loss: 7.7196 - val_pred_layer_2_loss: 0.6216 - val_pred_layer_0_loss: 0.9250 - val_pred_layer_1_loss: 0.7590 - val_pred_layer_2_acc: 0.8007 - val_pred_layer_0_acc: 0.6418 - val_pred_layer_0_acc_1: 0.6602 - val_pred_layer_0_acc_2: 0.6811 - val_pred_layer_1_acc: 0.6940 - val_pred_layer_1_acc_1: 0.7494 - val_pred_layer_1_acc_2: 0.7646 - val_pred_layer_2_acc_1: 0.7897 - val_pred_layer_2_acc_2: 0.8020
421 - pred_layer_2_acc_1: 0.8645 - pred_layer_2_acc_2: 0.8747 - val_loss: 7.1878 - val_pred_layer_2_loss: 0.5423 - val_pred_layer_0_loss: 0.9304 - val_pred_layer_1_loss: 0.6107 - val_pred_layer_2_acc: 0.8346 - val_pred_layer_0_acc: 0.6359 - val_pred_layer_0_acc_1: 0.6892 - val_pred_layer_0_acc_2: 0.6896 - val_pred_layer_1_acc: 0.7195 - val_pred_layer_1_acc_1: 0.7805 - val_pred_layer_1_acc_2: 0.8116 - val_pred_layer_2_acc_1: 0.8268 - val_pred_layer_2_acc_2: 0.8345
#
# Epoch 00049: val_pred_layer_2_acc did not improve from 0.84710
# Epoch 50/200
# Learning rate:  0.001
#  - 167s - loss: 5.7781 - pred_layer_2_loss: 0.3554 - pred_layer_0_loss: 0.8004 - pred_layer_1_loss: 0.4542 - pred_layer_2_acc: 0.8769 - pred_layer_0_acc: 0.6537 - pred_layer_0_acc_1: 0.7052 - pred_layer_0_acc_2: 0.7205 - pred_layer_1_acc: 0.7684 - pred_layer_1_acc_1: 0.8236 - pred_layer_1_acc_2: 0.8436 - pred_layer_2_acc_1: 0.8656 - pred_layer_2_acc_2: 0.8767 - val_loss: 6.5009 - val_pred_layer_2_loss: 0.4739 - val_pred_layer_0_loss: 0.8732 - val_pred_layer_1_loss: 0.5408 - val_pred_layer_2_acc: 0.8410 - val_pred_layer_0_acc: 0.6666 - val_pred_layer_0_acc_1: 0.6914 - val_pred_layer_0_acc_2: 0.6983 - val_pred_layer_1_acc: 0.7333 - val_pred_layer_1_acc_1: 0.7974 - val_pred_layer_1_acc_2: 0.8217 - val_pred_layer_2_acc_1: 0.8267 - val_pred_layer_2_acc_2: 0.8419
#
# Epoch 00050: val_pred_layer_2_acc did not improve from 0.84710
# Epoch 51/200
# Learning rate:  0.001
#  - 167s - loss: 5.7578 - pred_layer_2_loss: 0.3518 - pred_layer_0_loss: 0.7966 - pred_layer_1_loss: 0.4516 - pred_layer_2_acc: 0.8773 - pred_layer_0_acc: 0.6560 - pred_layer_0_acc_1: 0.7063 - pred_layer_0_acc_2: 0.7230 - pred_layer_1_acc: 0.7690 - pred_layer_1_acc_1: 0.8244 - pred_layer_1_acc_2: 0.8430 - pred_layer_2_acc_1: 0.8669 - pred_layer_2_acc_2: 0.8775 - val_loss: 6.3936 - val_pred_layer_2_loss: 0.4784 - val_pred_layer_0_loss: 0.8235 - val_pred_layer_1_loss: 0.5414 - val_pred_layer_2_acc: 0.8470 - val_pred_layer_0_acc: 0.6633 - val_pred_layer_0_acc_1: 0.7015 - val_pred_layer_0_acc_2: 0.7151 - val_pred_layer_1_acc: 0.7457 - val_pred_layer_1_acc_1: 0.8032 - val_pred_layer_1_acc_2: 0.8251 - val_pred_layer_2_acc_1: 0.8345 - val_pred_layer_2_acc_2: 0.8474
#
# Epoch 00051: val_pred_layer_2_acc did not improve from 0.84710
# Epoch 52/200
# Learning rate:  0.001
#  - 168s - loss: 5.7132 - pred_layer_2_loss: 0.3484 - pred_layer_0_loss: 0.7920 - pred_layer_1_loss: 0.4438 - pred_layer_2_acc: 0.8791 - pred_layer_0_acc: 0.6553 - pred_layer_0_acc_1: 0.7104 - pred_layer_0_acc_2: 0.7242 - pred_layer_1_acc: 0.7713 - pred_layer_1_acc_1: 0.8273 - pred_layer_1_acc_2: 0.8475 - pred_layer_2_acc_1: 0.8701 - pred_layer_2_acc_2: 0.8788 - val_loss: 6.5226 - val_pred_layer_2_loss: 0.5183 - val_pred_layer_0_loss: 0.8284 - val_pred_layer_1_loss: 0.5759 - val_pred_layer_2_acc: 0.8286 - val_pred_layer_0_acc: 0.6661 - val_pred_layer_0_acc_1: 0.7069 - val_pred_layer_0_acc_2: 0.7120 - val_pred_layer_1_acc: 0.7548 - val_pred_layer_1_acc_1: 0.8022 - val_pred_layer_1_acc_2: 0.8112 - val_pred_layer_2_acc_1: 0.8178 - val_pred_layer_2_acc_2: 0.8293
#
# Epoch 00052: val_pred_layer_2_acc did not improve from 0.84710
# Epoch 53/200
# Learning rate:  0.001
#  - 169s - loss: 5.7585 - pred_layer_2_loss: 0.3505 - pred_layer_0_loss: 0.7985 - pred_layer_1_loss: 0.4506 - pred_layer_2_acc: 0.8783 - pred_layer_0_acc: 0.6530 - pred_layer_0_acc_1: 0.7061 - pred_layer_0_acc_2: 0.7207 - pred_layer_1_acc: 0.7709 - pred_layer_1_acc_1: 0.8251 - pred_layer_1_acc_2: 0.8449 - pred_layer_2_acc_1: 0.8699 - pred_layer_2_acc_2: 0.8779 - val_loss: 7.7660 - val_pred_layer_2_loss: 0.6502 - val_pred_layer_0_loss: 0.9996 - val_pred_layer_1_loss: 0.7038 - val_pred_layer_2_acc: 0.7980 - val_pred_layer_0_acc: 0.6463 - val_pred_layer_0_acc_1: 0.6600 - val_pred_layer_0_acc_2: 0.6543 - val_pred_layer_1_acc: 0.6972 - val_pred_layer_1_acc_1: 0.7624 - val_pred_layer_1_acc_2: 0.7809 - val_pred_layer_2_acc_1: 0.7892 - val_pred_layer_2_acc_2: 0.7987
#
# Epoch 00053: val_pred_layer_2_acc did not improve from 0.84710
# Epoch 54/200
# Learning rate:  0.001
# ...
# Epoch 183/200
# Learning rate:  5e-07
#  - 169s - loss: 4.5099 - pred_layer_2_loss: 0.1585 - pred_layer_0_loss: 0.6983 - pred_layer_1_loss: 0.3093 - pred_layer_2_acc: 0.9450 - pred_layer_0_acc: 0.6853 - pred_layer_0_acc_1: 0.7382 - pred_layer_0_acc_2: 0.7558 - pred_layer_1_acc: 0.8118 - pred_layer_1_acc_1: 0.8692 - pred_layer_1_acc_2: 0.8913 - pred_layer_2_acc_1: 0.9253 - pred_layer_2_acc_2: 0.9448 - val_loss: 5.5079 - val_pred_layer_2_loss: 0.3821 - val_pred_layer_0_loss: 0.7349 - val_pred_layer_1_loss: 0.4490 - val_pred_layer_2_acc: 0.8850 - val_pred_layer_0_acc: 0.6856 - val_pred_layer_0_acc_1: 0.7332 - val_pred_layer_0_acc_2: 0.7445 - val_pred_layer_1_acc: 0.7897 - val_pred_layer_1_acc_1: 0.8386 - val_pred_layer_1_acc_2: 0.8568 - val_pred_layer_2_acc_1: 0.8741 - val_pred_layer_2_acc_2: 0.8846
#
# Epoch 00183: val_pred_layer_2_acc did not improve from 0.88570
# Epoch
val_pred_layer_2_acc did not improve from 0.88570
# Epoch 193/200
# Learning rate:  5e-07
#  - 169s - loss: 4.5339 - pred_layer_2_loss: 0.1613 - pred_layer_0_loss: 0.6995 - pred_layer_1_loss: 0.3121 - pred_layer_2_acc: 0.9439 - pred_layer_0_acc: 0.6866 - pred_layer_0_acc_1: 0.7400 - pred_layer_0_acc_2: 0.7570 - pred_layer_1_acc: 0.8089 - pred_layer_1_acc_1: 0.8667 - pred_layer_1_acc_2: 0.8912 - pred_layer_2_acc_1: 0.9252 - pred_layer_2_acc_2: 0.9437 - val_loss: 5.5133 - val_pred_layer_2_loss: 0.3829 - val_pred_layer_0_loss: 0.7353 - val_pred_layer_1_loss: 0.4493 - val_pred_layer_2_acc: 0.8850 - val_pred_layer_0_acc: 0.6854 - val_pred_layer_0_acc_1: 0.7330 - val_pred_layer_0_acc_2: 0.7443 - val_pred_layer_1_acc: 0.7894 - val_pred_layer_1_acc_1: 0.8383 - val_pred_layer_1_acc_2: 0.8571 - val_pred_layer_2_acc_1: 0.8743 - val_pred_layer_2_acc_2: 0.8844
#
# Epoch 00193: val_pred_layer_2_acc did not improve from 0.88570
# Epoch 194/200
# Learning rate:  5e-07
#  - 170s - loss: 4.5522 - pred_layer_2_loss: 0.1641 - pred_layer_0_loss: 0.7006 - pred_layer_1_loss: 0.3134 - pred_layer_2_acc: 0.9416 - pred_layer_0_acc: 0.6871 - pred_layer_0_acc_1: 0.7390 - pred_layer_0_acc_2: 0.7572 - pred_layer_1_acc: 0.8102 - pred_layer_1_acc_1: 0.8675 - pred_layer_1_acc_2: 0.8907 - pred_layer_2_acc_1: 0.9248 - pred_layer_2_acc_2: 0.9416 - val_loss: 5.5165 - val_pred_layer_2_loss: 0.3827 - val_pred_layer_0_loss: 0.7361 - val_pred_layer_1_loss: 0.4495 - val_pred_layer_2_acc: 0.8853 - val_pred_layer_0_acc: 0.6846 - val_pred_layer_0_acc_1: 0.7332 - val_pred_layer_0_acc_2: 0.7430 - val_pred_layer_1_acc: 0.7898 - val_pred_layer_1_acc_1: 0.8384 - val_pred_layer_1_acc_2: 0.8571 - val_pred_layer_2_acc_1: 0.8746 - val_pred_layer_2_acc_2: 0.8853
#
# Epoch 00194: val_pred_layer_2_acc did not improve from 0.88570
# Epoch 195/200
# Learning rate:  5e-07
#  - 168s - loss: 4.5399 - pred_layer_2_loss: 0.1615 - pred_layer_0_loss: 0.6981 - pred_layer_1_loss: 0.3122 - pred_layer_2_acc: 0.9432 - pred_layer_0_acc: 0.6863 - pred_layer_0_acc_1: 0.7405 - pred_layer_0_acc_2: 0.7591 - pred_layer_1_acc: 0.8102 - pred_layer_1_acc_1: 0.8681 - pred_layer_1_acc_2: 0.8917 - pred_layer_2_acc_1: 0.9249 - pred_layer_2_acc_2: 0.9431 - val_loss: 5.5326 - val_pred_layer_2_loss: 0.3833 - val_pred_layer_0_loss: 0.7380 - val_pred_layer_1_loss: 0.4515 - val_pred_layer_2_acc: 0.8847 - val_pred_layer_0_acc: 0.6845 - val_pred_layer_0_acc_1: 0.7325 - val_pred_layer_0_acc_2: 0.7432 - val_pred_layer_1_acc: 0.7887 - val_pred_layer_1_acc_1: 0.8377 - val_pred_layer_1_acc_2: 0.8561 - val_pred_layer_2_acc_1: 0.8737 - val_pred_layer_2_acc_2: 0.8844
#
# Epoch 00195: val_pred_layer_2_acc did not improve from 0.88570
# Epoch
val_pred_layer_2_acc did not improve from 0.88570
# Epoch 199/200
# Learning rate:  5e-07
#  - 168s - loss: 4.5298 - pred_layer_2_loss: 0.1622 - pred_layer_0_loss: 0.6972 - pred_layer_1_loss: 0.3091 - pred_layer_2_acc: 0.9442 - pred_layer_0_acc: 0.6854 - pred_layer_0_acc_1: 0.7421 - pred_layer_0_acc_2: 0.7592 - pred_layer_1_acc: 0.8103 - pred_layer_1_acc_1: 0.8666 - pred_layer_1_acc_2: 0.8919 - pred_layer_2_acc_1: 0.9263 - pred_layer_2_acc_2: 0.9443 - val_loss: 5.5053 - val_pred_layer_2_loss: 0.3827 - val_pred_layer_0_loss: 0.7340 - val_pred_layer_1_loss: 0.4489 - val_pred_layer_2_acc: 0.8846 - val_pred_layer_0_acc: 0.6864 - val_pred_layer_0_acc_1: 0.7344 - val_pred_layer_0_acc_2: 0.7436 - val_pred_layer_1_acc: 0.7900 - val_pred_layer_1_acc_1: 0.8390 - val_pred_layer_1_acc_2: 0.8566 - val_pred_layer_2_acc_1: 0.8745 - val_pred_layer_2_acc_2: 0.8842
#
# Epoch 00199: val_pred_layer_2_acc did not improve from 0.88570
# Epoch 200/200
# Learning rate:  5e-07
#  - 169s - loss: 4.5554 - pred_layer_2_loss: 0.1615 - pred_layer_0_loss: 0.7071 - pred_layer_1_loss: 0.3116 - pred_layer_2_acc: 0.9434 - pred_layer_0_acc: 0.6848 - pred_layer_0_acc_1: 0.7362 - pred_layer_0_acc_2: 0.7538 - pred_layer_1_acc: 0.8058 - pred_layer_1_acc_1: 0.8674 - pred_layer_1_acc_2: 0.8906 - pred_layer_2_acc_1: 0.9248 - pred_layer_2_acc_2: 0.9435 - val_loss: 5.5182 - val_pred_layer_2_loss: 0.3834 - val_pred_layer_0_loss: 0.7365 - val_pred_layer_1_loss: 0.4502 - val_pred_layer_2_acc: 0.8842 - val_pred_layer_0_acc: 0.6847 - val_pred_layer_0_acc_1: 0.7332 - val_pred_layer_0_acc_2: 0.7433 - val_pred_layer_1_acc: 0.7893 - val_pred_layer_1_acc_1: 0.8378 - val_pred_layer_1_acc_2: 0.8564 - val_pred_layer_2_acc_1: 0.8745 - val_pred_layer_2_acc_2: 0.8836
#
# Epoch 00200: val_pred_layer_2_acc did not improve from 0.88570
# 10000/10000 [==============================] - 9s 913us/step
# Test output: [5.518213678741455, 0.38147677904963495, 0.8948055968284607, 0.7641262567043304, 0.7364691847324372, 0.6161728966712952, 0.48370333206653593, 0.45023105161190036, 0.4024183526396751, 0.38341137510538104, 0.8842, 0.6847, 0.7332, 0.7433, 0.7893, 0.8378, 0.8564, 0.8745, 0.8836]

# %%
os.path.join(save_dir, model_name)
# Out:
# '/content/gdrive/My Drive/colab/weights/boost_cifar10_ResNet20v1_model.{epoch:03d}.h5'

# %%
model.save_weights(os.path.join(save_dir, "boost_cifar10_ResNet20v1_model.final_200.h5"))
